# %% [markdown]
# # THIS FILE SHOULD BE DELETED AT THE END
# It is just for testing the code

# %%
from rasa_sdk import Action
from rasa_sdk.events import SlotSet
import zomatopy
import json
import re

# %%
class ActionSearchRestaurants(Action):
	def name(self):
		return 'action_search_restaurants'
		
	def run(self, dispatcher, tracker, domain):
		config={ "user_key":"f9c893da39750138e222b042c8070293"}
		zomato = zomatopy.initialize_app(config)
		# specify location and cuisine
		#loc = 'Bangalore'
		#cuisine = 'Italian'
		loc = tracker.get_slot('location')
		cuisine = tracker.get_slot('cuisine')
		# get_location gets the lat-long coordinates of 'loc'
		location_detail=zomato.get_location(loc, 1)
		# store retrieved data as a dict
		d1 = json.loads(location_detail)
		# separate lat-long coordinates
		lat=d1["location_suggestions"][0]["latitude"]
		lon=d1["location_suggestions"][0]["longitude"]
		# cuisines code (used by zomatopy)
		cuisines_dict={'bakery':5,'chinese':25,'cafe':30,'italian':55,'biryani':7,'north indian':50,'south indian':85}
		# fetch and print results
		results=zomato.restaurant_search("", lat, lon, str(cuisines_dict.get(cuisine)), 5)
		d = json.loads(results)
		response=""
		if d['results_found'] == 0:
			response= "no results"
		else:
			for restaurant in d['restaurants']:
				response=response+ "Found "+ restaurant['restaurant']['name']+ " in "+ restaurant['restaurant']['location']['address']+"\n"
		
		dispatcher.utter_message("-----"+response)
		return [SlotSet('location',loc)]

# %%
abc = ActionSearchRestaurants()
abc

# %%
config={ "user_key":"f9c893da39750138e222b042c8070293"}
zomato = zomatopy.initialize_app(config)

# %%
loc = 'Bangalore'
cuisine = 'Italian'
location_detail=zomato.get_location(loc, 1)
location_detail
# Out:
# '{"location_suggestions":[{"entity_type":"group","entity_id":661,"title":"Bangalore Central, JP Nagar, Bengaluru","latitude":12.9165654437,"longitude":77.5922673941,"city_id":4,"city_name":"Bengaluru","country_id":1,"country_name":"India"}],"status":"success","has_more":0,"has_total":0,"user_has_addresses":true}'

# %%
d1 = json.loads(location_detail)
            # Separate lat-long coordinates
lat = d1["location_suggestions"][0]["latitude"]
lon = d1["location_suggestions"][0]["longitude"]

# %%
lon
# Out:
# 77.5922673941

# %%
cuisines_dict={'bakery':5,'chinese':25,'cafe':30,'italian':55,'biryani':7,'north indian':50,'south indian':85}
#d1 = json.loads(location_detail)
#lat=d1["location_suggestions"][0]["latitude"]
#lon=d1["location_suggestions"][0]["longitude"]
lat = '12.9129344258',
lon = '77.6829059422'
cuisines_dict={'bakery':5,'chinese':25,'cafe':30,'italian':55,'biryani':7,'north indian':50,'south indian':85}
print(str(cuisines_dict.get("chinese")))
results=zomato.restaurant_search("", lat, lon, str(cuisines_dict.get("chinese")), 10)
d = json.loads(results)
# Out:
# 25

# %%
results
# Out:
# '{"results_found":158765,"results_start":0,"results_shown":10,"restaurants":[{"restaurant":{"R":{"has_menu_status":{"delivery":-1,"takeaway":-1},"res_id":18483051,"is_grocery_store":false},"apikey":"f9c893da39750138e222b042c8070293","id":"18483051","name":"Summer Pavilion","url":"https:\\/\\/www.zomato.com\\/singapore\\/summer-pavilion-downtown-core?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1","location":{"address":"The Ritz-Carlton, 7 Raffles Avenue,  Millenia Singapore,  039799","locality":"Marina Centre, Downtown Core","city":"Singapore","city_id":52,"latitude":"1.2908008811","longitude":"103.8601766110","zipcode":"039799","country_id":184,"locality_verbose":"Marina Centre, Downtown Core, Singapore"},"switch_to_order_menu":0,"cuisines":"Chinese, Seafood, Cantonese, Dim Sum","timings":"11:30 AM to 2:30 PM, 6:30 PM to 10:30 PM (Mon-Sun)","average_cost_for_two":300,"price_range":4,"currency":"$","highlights":["Cash","Debit Card","Takeaway Available","Breakfast","Dinner","Credit Card","Lunch","Indoor Seating","Kid Friendly","Private Dining Area Available","High Tea","Wine","Table booking recommended","Air Conditioned","Luxury Dining","Brunch","Michelin Starred"],"offers":[],"opentable_support":0,"is_zomato_book_res":0,"mezzo_provider":"QUANDOO","is_book_form_web_view":0,"book_form_web_view_url":"","thumb":"https:\\/\\/b.zmtcdn.com\\/data\\/res_imagery\\/18483051_RESTAURANT_52d346fb945edfd971334b76e76a4b72.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A","user_rating":{"aggregate_rating":"3.7","rating_text":"Good","rating_color":"9ACD32","rating_obj":{"title":{"text":"3.7"},"bg_color":{"type":"lime","tint":"600"}},"votes":42},"all_reviews_count":32,"photos_url":"https:\\/\\/www.zomato.com\\/singapore\\/summer-pavilion-downtown-core\\/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop","photo_count":183,"menu_url":"https:\\/\\/www.zomato.com\\/singapore\\/summer-pavilion-downtown-core\\/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop","featured_image":"https:\\/\\/b.zmtcdn.com\\/data\\/res_imagery\\/18483051_RESTAURANT_52d346fb945edfd971334b76e76a4b72.jpg","medio_provider":"","has_online_delivery":0,"is_delivering_now":0,"store_type":"","include_bogo_offers":true,"deeplink":"zomato:\\/\\/restaurant\\/18483051","is_table_reservation_supported":0,"has_table_booking":1,"book_url":"https:\\/\\/www.zomato.com\\/singapore\\/summer-pavilion-downtown-core\\/book?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1","events_url":"https:\\/\\/www.zomato.com\\/singapore\\/summer-pavilion-downtown-core\\/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1","phone_numbers":"64345286","all_reviews":{"reviews":[{"review":[]},{"review":[]},{"review":[]},{"review":[]},{"review":[]}]},"establishment":["Fine Dining"],"establishment_types":[]}},{"restaurant":{"R":{"has_menu_status":{"delivery":-1,"takeaway":-1},"res_id":18496050,"is_grocery_store":false},"apikey":"f9c893da39750138e222b042c8070293","id":"18496050","name":"Wing Seong Fatty\'s Restaurant","url":"https:\\/\\/www.zomato.com\\/singapore\\/wing-seong-fattys-restaurant-rochor?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1","location":{"address":"175 Bencoolen Street, #01-31 Burlington Square 189649","locality":"Bencoolen Street, Rochor","city":"Singapore","city_id":52,"latitude":"1.3022222106","longitude":"103.8525782260","zipcode":"189649","country_id":184,"locality_verbose":"Bencoolen Street, Rochor, Singapore"},"switch_to_order_menu":0,"cuisines":"Asian, Chinese","timings":"12 Noon to 2:30 PM, 5 PM to 10:30 PM (Mon-Sun)","average_cost_for_two":30,"price_range":3,"currency":"$","highlights":["Cash","No Alcohol Available","Dinner","Takeaway Available","Lunch","Air Conditioned","Indoor Seating","Table booking recommended"],"offers":[],"opentable_support":0,"is_zomato_book_res":0,"mezzo_provider":"OTHER","is_book_form_web_view":0,"book_form_web_view_url":"" ...

# %%
d
# Out:
# {'results_found': 158765,
#  'results_start': 0,
#  'results_shown': 10,
#  'restaurants': [{'restaurant': {'R': {'has_menu_status': {'delivery': -1,
#       'takeaway': -1},
#      'res_id': 18483051,
#      'is_grocery_store': False},
#     'apikey': 'f9c893da39750138e222b042c8070293',
#     'id': '18483051',
#     'name': 'Summer Pavilion',
#     'url': 'https://www.zomato.com/singapore/summer-pavilion-downtown-core?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'The Ritz-Carlton, 7 Raffles Avenue,  Millenia Singapore,  039799',
#      'locality': 'Marina Centre, Downtown Core',
#      'city': 'Singapore',
#      'city_id': 52,
#      'latitude': '1.2908008811',
#      'longitude': '103.8601766110',
#      'zipcode': '039799',
#      'country_id': 184,
#      'locality_verbose': 'Marina Centre, Downtown Core, Singapore'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Chinese, Seafood, Cantonese, Dim Sum',
#     'timings': '11:30 AM to 2:30 PM, 6:30 PM to 10:30 PM (Mon-Sun)',
#     'average_cost_for_two': 300,
#     'price_range': 4,
#     'currency': '$',
#     'highlights': ['Cash',
#      'Debit Card',
#      'Takeaway Available',
#      'Breakfast',
#      'Dinner',
#      'Credit Card',
#      'Lunch',
#      'Indoor Seating',
#      'Kid Friendly',
#      'Private Dining Area Available',
#      'High Tea',
#      'Wine',
#      'Table booking recommended',
#      'Air Conditioned',
#      'Luxury Dining',
#      'Brunch',
#      'Michelin Starred'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'QUANDOO',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/res_imagery/18483051_RESTAURANT_52d346fb945edfd971334b76e76a4b72.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '3.7',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.7'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 42},
#     'all_reviews_count': 32,
#     'photos_url': 'https://www.zomato.com/singapore/summer-pavilion-downtown-core/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 183,
#     'menu_url': 'https://www.zomato.com/singapore/summer-pavilion-downtown-core/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/res_imagery/18483051_RESTAURANT_52d346fb945edfd971334b76e76a4b72.jpg',
#     'medio_provider': '',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18483051',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 1,
#     'book_url': 'https://www.zomato.com/singapore/summer-pavilion-downtown-core/book?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'events_url': 'https://www.zomato.com/singapore/summer-pavilion-downtown-core/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '64345286',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Fine Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 18496050,
#      'is_grocery_store': False},
#     'apikey': 'f9c893da39750138e222b042c8070293',
#     'id': '18496050',
#     'name': "Wing Seong Fatty's Restaurant",
#     'url': 'https://www.zomato.com/singapore/wing-seong-fattys-restaurant-rochor?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '175 Bencoolen Street, #01-31 Burlington Square 189649',
#      'locality': 'Bencoolen Street, Rochor',
#      'city': 'Singapore',
#      'city_id': 52,
#      'latitude': '1.3022222106',
#      'longitude': '103.8525782260',
#      'zipcode': '189649',
#      'country_id': 184,
#      'locality_verbose': 'Bencoolen Street, Rochor, Singapore'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Asian, Chinese',
#     'timings': '12 Noon to 2:30 PM, 5 PM to 10:30 PM (Mon-Sun)',
#     'average_cost_for_two': 30,
#     'price_range': 3,
#     'currency': '$',
#     'highlights': ['Cash',
#      'No Alcohol Available',
#      'Dinner',
#      'Takeaway Available',
#      'Lunch',
#      'Air Conditioned',
#      'Indoor Seating',
#      'Table booking recommended'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '3.2',
#      'rating_text': 'Average',
#      'rating_color': 'CDD614',
#      'rating_obj': {'title': {'text': '3.2'},
#       'bg_color': {'type': 'lime', 'tint': '500'}},
#      'votes': 15},
#     'all_reviews_count': 12,
#     'photos_url': 'https://www.zomato.com/singapore/wing-seong-fattys-restaurant-rochor/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 102,
#     'menu_url': 'https://www.zomato.com/singapore/wing-seong-fattys-restaurant-rochor/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18496050',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/singapore/wing-seong-fattys-restaurant-rochor/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '63381087',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 18482703,
#      'is_grocery_store': False},
#     'apikey': 'f9c893da39750138e222b042c8070293',
#     'id': '18482703',
#     'name': 'Keng Eng Kee Seafood',
#     'url': 'https://www.zomato.com/singapore/keng-eng-kee-seafood-bukit-merah?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '124 Bukit Merah Lane 1, #01-136 150124',
#      'locality': 'Alexandra Hill, Bukit Merah',
#      'city': 'Singapore',
#      'city_id': 52,
#      'latitude': '1.2858512207',
#      'longitude': '103.8037019370',
#      'zipcode': '150124',
#      'country_id': 184,
#      'locality_verbose': 'Alexandra Hill, Bukit Merah, Singapore'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Hainanese, Chinese, Seafood',
#     'timings': '12 Noon to 10 PM (Mon-Sun)',
#     'average_cost_for_two': 60,
#     'price_range': 4,
#     'currency': '$',
#     'highlights': ['Cash',
#      'Takeaway Available',
#      'Dinner',
#      'Lunch',
#      'Kid Friendly',
#      'Indoor Seating',
#      'Table booking recommended'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '3.9',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.9'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 7},
#     'all_reviews_count': 5,
#     'photos_url': 'https://www.zomato.com/singapore/keng-eng-kee-seafood-bukit-merah/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 5,
#     'menu_url': 'https://www.zomato.com/singapore/keng-eng-kee-seafood-bukit-merah/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18482703',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/singapore/keng-eng-kee-seafood-bukit-merah/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '62721038',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 18695063,
#      'is_grocery_store': False},
#     'apikey': 'f9c893da39750138e222b042c8070293',
#     'id': '18695063',
#     'name': 'Boa-Bao',
#     'url': 'https://www.zomato.com/boabaoporto?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Rua da Picaria, 61-65, Baixa, Porto',
#      'locality': 'Baixa',
#      'city': 'Porto',
#      'city_id': 311,
#      'latitude': '41.1492769903',
#      'longitude': '-8.6130086705',
#      'zipcode': '',
#      'country_id': 164,
#      'locality_verbose': 'Baixa, Porto'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Oriental, Thai, Malaysian, Filipino, Vietnamese, Korean, Chinese, Japanese',
#     'timings': '19:00 – 22:00 (Mon, Tue, Thu), Closed (Wed),19:00 – 23:00 (Fri),12:00 – 15:00, 19:00 – 23:00 (Sat),12:00 – 15:00, 19:00 – 22:00 (Sun)',
#     'average_cost_for_two': 48,
#     'price_range': 4,
#     'currency': '€',
#     'highlights': ['Credit Card',
#      'Lunch',
#      'Serves Alcohol',
#      'Cash',
#      'Takeaway Available',
#      'Debit Card',
#      'Dinner',
#      'Wifi',
#      'Vegan Options',
#      'Fullbar',
#      'Indoor Seating',
#      'Pet Friendly',
#      'Vegetarian Friendly',
#      'Outdoor Seating',
#      'Serves Cocktails',
#      'Table booking recommended'],
#     'offers': [],
#     'zomato_events': [{'event': {'event_id': 472997,
#        'friendly_start_date': '21 October',
#        'friendly_end_date': '30 November',
#        'friendly_timing_str': 'Wednesday, 21st October - Monday, 30th November',
#        'start_date': '2020-10-21',
#        'end_date': '2020-11-30',
#        'end_time': '19:00:00',
#        'start_time': '18:00:00',
#        'is_active': 1,
#        'date_added': '2020-10-21 21:32:59',
#        'photos': [{'photo': {'url': 'https://b.zmtcdn.com/data/zomato_events/photos/590/f3f7700c93ca571a2f524c4128213590_1603296195.jpg',
#           'thumb_url': 'https://b.zmtcdn.com/data/zomato_events/photos/590/f3f7700c93ca571a2f524c4128213590_1603296195.jpg?fit=around%7C100%3A100&crop=100%3A100%3B%2A%2C%2A',
#           'order': 0,
#           'md5sum': 'f3f7700c93ca571a2f524c4128213590',
#           'id': 640476,
#           'photo_id': 640476,
#           'uuid': 1603296189374419,
#           'type': 'NORMAL'}}],
#        'restaurants': [],
#        'is_valid': 1,
#        'share_url': 'http://www.zoma.to/r/0',
#        'show_share_url': 0,
#        'title': 'BOA-BAO | GIFT CARDS',
#        'description': 'Os melhores presentes da vida? Partilhar momentos inesquecíveis. Surpreenda os seus amigos e família com a nossa Asian food journey através dos gift cards BOA-BAO (20€, 30€ e 50€). Mais informações por email ola@boabao.pt!',
#        'display_time': '06:00 pm - 07:00 pm',
#        'display_date': '21 October - 30 November',
#        'is_end_time_set': 1,
#        'disclaimer': 'Restaurants are solely responsible for the service; availability and quality of the events including all or any cancellations/ modifications/ complaints.',
#        'event_category': 0,
#        'event_category_name': '',
#        'book_link': '',
#        'types': [],
#        'share_data': {'should_show': 0}}}],
#     'opentable_support': 0,
#     'is_zomato_book_res': 1,
#     'mezzo_provider': 'ZOMATO_BOOK',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/chains/3/18695063/668275c9a2dfbe6c4a756586b70e9b7c.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.7',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'rating_obj': {'title': {'text': '4.7'},
#       'bg_color': {'type': 'lime', 'tint': '800'}},
#      'votes': 1127},
#     'all_reviews_count': 429,
#     'photos_url': 'https://www.zomato.com/boabaoporto/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 1144,
#     'menu_url': 'https://www.zomato.com/boabaoporto/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/chains/3/18695063/668275c9a2dfbe6c4a756586b70e9b7c.jpg',
#     'medio_provider': '',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18695063',
#     'is_table_reservation_supported': 1,
#     'has_table_booking': 1,
#     'book_url': 'https://www.zomato.com/boabaoporto/book?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'events_url': 'https://www.zomato.com/boabaoporto/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '910043030',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 19040030,
#      'is_grocery_store': False},
#     'apikey': 'f9c893da39750138e222b042c8070293',
#     'id': '19040030',
#     'name': 'Yum Chinese',
#     'url': 'https://www.zomato.com/balasore/yum-chinese-balasore-locality?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'OT road, Balasore, Balasore Locality, Balasore',
#      'locality': 'Balasore Locality',
#      'city': 'Balasore',
#      'city_id': 11489,
#      'latitude': '21.4814977418',
#      'longitude': '86.9068929926',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Balasore Locality, Balasore'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Chinese',
#     'timings': '11 AM to 10:30 PM',
#     'average_cost_for_two': 400,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Takeaway Available',
#      'Cash',
#      'Dinner',
#      'Delivery',
#      'Lunch',
#      'Indoor Seating',
#      'Brunch',
#      'Air Conditioned',
#      'Desserts and Bakes'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '4.7',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'rating_obj': {'title': {'text': '4.7'},
#       'bg_color': {'type': 'lime', 'tint': '800'}},
#      'votes': 2061},
#     'all_reviews_count': 24,
#     'photos_url': 'https://www.zomato.com/balasore/yum-chinese-balasore-locality/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 12,
#     'menu_url': 'https://www.zomato.com/balasore/yum-chinese-balasore-locality/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/19040030',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/balasore/yum-chinese-balasore-locality/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9583095835',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 17692852,
#      'is_grocery_store': False},
#     'apikey': 'f9c893da39750138e222b042c8070293',
#     'id': '17692852',
#     'name': 'O K Chinese Restaurant',
#     'url': 'https://www.zomato.com/oak-hill-wv/o-k-chinese-restaurant-oak-hill?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': '637 Fayette Sq, Oak Hill 25901',
#      'locality': 'Oak Hill',
#      'city': 'Oak Hill',
#      'city_id': 10392,
#      'latitude': '38.0126000000',
#      'longitude': '-81.1308000000',
#      'zipcode': '25901',
#      'country_id': 216,
#      'locality_verbose': 'Oak Hill, Oak Hill'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Chinese',
#     'timings': '',
#     'average_cost_for_two': 0,
#     'price_range': 1,
#     'currency': '$',
#     'highlights': ['Lunch', 'Dinner'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '3.9',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.9'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 6},
#     'all_reviews_count': 2,
#     'photos_url': 'https://www.zomato.com/oak-hill-wv/o-k-chinese-restaurant-oak-hill/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 0,
#     'menu_url': 'https://www.zomato.com/oak-hill-wv/o-k-chinese-restaurant-oak-hill/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/17692852',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/oak-hill-wv/o-k-chinese-restaurant-oak-hill/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '(304) 465-8465',
#     'all_reviews': {'reviews': [{'review': []}, {'review': []}]},
#     'establishment': [],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 19029874,
#      'is_grocery_store': False},
#     'apikey': 'f9c893da39750138e222b042c8070293',
#     'id': '19029874',
#     'name': 'The Fat Chicken',
#     'url': 'https://www.zomato.com/agartala/the-fat-chicken-krishna-nagar-agartala?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'RMS Chowmuhani, Krishna Nagar, Agartala',
#      'locality': 'Krishna Nagar',
#      'city': 'Agartala ',
#      'city_id': 11340,
#      'latitude': '23.8317566947',
#      'longitude': '91.2786393984',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Krishna Nagar, Agartala '},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Chinese, Momos',
#     'timings': '12 Noon to 10:30 PM',
#     'average_cost_for_two': 350,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Dinner',
#      'Takeaway Available',
#      'Lunch',
#      'Cash',
#      'Indoor Seating'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '3.6',
#      'rating_text': 'Good',
#      'rating_color': '9ACD32',
#      'rating_obj': {'title': {'text': '3.6'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 2748},
#     'all_reviews_count': 19,
#     'photos_url': 'https://www.zomato.com/agartala/the-fat-chicken-krishna-nagar-agartala/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 4,
#     'menu_url': 'https://www.zomato.com/agartala/the-fat-chicken-krishna-nagar-agartala/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/19029874',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/agartala/the-fat-chicken-krishna-nagar-agartala/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 8974296266',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Quick Bites'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 18487870,
#      'is_grocery_store': False},
#     'apikey': 'f9c893da39750138e222b042c8070293',
#     'id': '18487870',
#     'name': 'Boa-Bao',
#     'url': 'https://www.zomato.com/boabao?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Largo Rafael Bordalo Pinheiro, 30, Chiado, Lisboa 1200-369',
#      'locality': 'Chiado',
#      'city': 'Lisboa',
#      'city_id': 82,
#      'latitude': '38.7116519123',
#      'longitude': '-9.1415812075',
#      'zipcode': '1200-369',
#      'country_id': 164,
#      'locality_verbose': 'Chiado, Lisboa'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Oriental, Thai, Malaysian, Filipino, Vietnamese, Korean, Japanese, Chinese',
#     'timings': '18:30 – 22:30 (Mon-Tue),12:00 – 15:00, 18:30 – 22:30 (Wed, Thu, Sun), 12:00 – 15:00, 18:30 – 23:00 (Fri-Sat)',
#     'average_cost_for_two': 48,
#     'price_range': 4,
#     'currency': '€',
#     'highlights': ['Lunch',
#      'Dinner',
#      'Serves Alcohol',
#      'Takeaway Available',
#      'Debit Card',
#      'Credit Card',
#      'Wifi',
#      'Serves Cocktails',
#      'Table booking recommended',
#      'Vegetarian Friendly',
#      'Smoking Area',
#      'Fullbar',
#      'Indoor Seating',
#      'Wine',
#      'Outdoor Seating'],
#     'offers': [],
#     'zomato_events': [{'event': {'event_id': 472980,
#        'friendly_start_date': '21 October',
#        'friendly_end_date': '30 November',
#        'friendly_timing_str': 'Wednesday, 21st October - Monday, 30th November',
#        'start_date': '2020-10-21',
#        'end_date': '2020-11-30',
#        'end_time': '16:00:00',
#        'start_time': '15:00:00',
#        'is_active': 1,
#        'date_added': '2020-10-21 18:54:34',
#        'photos': [{'photo': {'url': 'https://b.zmtcdn.com/data/zomato_events/photos/590/f3f7700c93ca571a2f524c4128213590_1603286693.jpg',
#           'thumb_url': 'https://b.zmtcdn.com/data/zomato_events/photos/590/f3f7700c93ca571a2f524c4128213590_1603286693.jpg?fit=around%7C100%3A100&crop=100%3A100%3B%2A%2C%2A',
#           'order': 0,
#           'md5sum': 'f3f7700c93ca571a2f524c4128213590',
#           'id': 640440,
#           'photo_id': 640440,
#           'uuid': 1603286688089883,
#           'type': 'NORMAL'}}],
#        'restaurants': [],
#        'is_valid': 1,
#        'share_url': 'http://www.zoma.to/r/0',
#        'show_share_url': 0,
#        'title': 'BOA-BAO | GIFT CARDS',
#        'description': 'Os melhores presentes da vida? Partilhar momentos inesquecíveis. Surpreenda os seus amigos e família com a nossa Asian food journey através dos gift cards BOA-BAO (20€, 30€ e 50€). Mais informações por email ola@boabao.pt!',
#        'display_time': '03:00 pm - 04:00 pm',
#        'display_date': '21 October - 30 November',
#        'is_end_time_set': 1,
#        'disclaimer': 'Restaurants are solely responsible for the service; availability and quality of the events including all or any cancellations/ modifications/ complaints.',
#        'event_category': 0,
#        'event_category_name': '',
#        'book_link': '',
#        'types': [],
#        'share_data': {'should_show': 0}}}],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/chains/0/18487870/b0e39d38e733f299915ccd05701ff066.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.7',
#      'rating_text': 'Excellent',
#      'rating_color': '3F7E00',
#      'rating_obj': {'title': {'text': '4.7'},
#       'bg_color': {'type': 'lime', 'tint': '800'}},
#      'votes': 4739},
#     'all_reviews_count': 1771,
#     'photos_url': 'https://www.zomato.com/boabao/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 4030,
#     'menu_url': 'https://www.zomato.com/boabao/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/chains/0/18487870/b0e39d38e733f299915ccd05701ff066.jpg',
#     'has_online_delivery': 0,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18487870',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/boabao/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '919023030',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': 1, 'takeaway': -1},
#      'res_id': 18498298,
#      'is_grocery_store': False},
#     'apikey': 'f9c893da39750138e222b042c8070293',
#     'id': '18498298',
#     'name': 'WOK BOYZ - ووك بويز',
#     'url': 'https://www.zomato.com/dubai/wok-boyz-trade-centre-area?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Al Durrah Tower, Next To Crowne Plaza Dubai, Sheikh Zayed Road, Trade Centre Area, Dubai',
#      'locality': 'Trade Centre Area',
#      'city': 'Dubai',
#      'city_id': 51,
#      'latitude': '25.2195237488',
#      'longitude': '55.2798520401',
#      'zipcode': '',
#      'country_id': 214,
#      'locality_verbose': 'Trade Centre Area, Dubai'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Asian, Thai, Chinese',
#     'timings': '11:30am – 11:15pm (Mon-Sun)',
#     'average_cost_for_two': 105,
#     'price_range': 3,
#     'currency': 'AED',
#     'highlights': ['Delivery',
#      'Cash',
#      'Credit Card',
#      'Debit Card',
#      'Takeaway Available',
#      'No Alcohol Available',
#      'Lunch',
#      'Dinner',
#      'Indoor Seating',
#      'Gluten Free Options',
#      'Outdoor Seating',
#      'Table booking recommended'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': 'https://b.zmtcdn.com/data/pictures/0/18668060/ea410fec006ec51d4e87c94aab71d780.png?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A',
#     'user_rating': {'aggregate_rating': '4.0',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.0'},
#       'bg_color': {'type': 'lime', 'tint': '600'}},
#      'votes': 11040},
#     'all_reviews_count': 938,
#     'photos_url': 'https://www.zomato.com/dubai/wok-boyz-trade-centre-area/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 874,
#     'menu_url': 'https://www.zomato.com/dubai/wok-boyz-trade-centre-area/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': 'https://b.zmtcdn.com/data/pictures/0/18668060/ea410fec006ec51d4e87c94aab71d780.png?output-format=webp',
#     'has_online_delivery': 1,
#     'is_delivering_now': 1,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/18498298',
#     'order_url': 'https://www.zomato.com/dubai/wok-boyz-trade-centre-area/order?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'order_deeplink': '',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/dubai/wok-boyz-trade-centre-area/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '600500965',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Casual Dining'],
#     'establishment_types': []}},
#   {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1},
#      'res_id': 2100753,
#      'is_grocery_store': False},
#     'apikey': 'f9c893da39750138e222b042c8070293',
#     'id': '2100753',
#     'name': "John's Kitchen",
#     'url': 'https://www.zomato.com/guwahati/johns-kitchen-christian-basti?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'location': {'address': 'Opposite MP Jewelers, Post Office, GS Road, Christian Basti, Guwahati',
#      'locality': 'Christian Basti',
#      'city': 'Guwahati',
#      'city_id': 21,
#      'latitude': '26.1596809059',
#      'longitude': '91.7736814544',
#      'zipcode': '',
#      'country_id': 1,
#      'locality_verbose': 'Christian Basti, Guwahati'},
#     'switch_to_order_menu': 0,
#     'cuisines': 'Chinese, Momos',
#     'timings': '1:30 PM to 10 PM (Mon-Sun)',
#     'average_cost_for_two': 350,
#     'price_range': 2,
#     'currency': 'Rs.',
#     'highlights': ['Delivery', 'Dinner', 'Cash', 'Indoor Seating'],
#     'offers': [],
#     'opentable_support': 0,
#     'is_zomato_book_res': 0,
#     'mezzo_provider': 'OTHER',
#     'is_book_form_web_view': 0,
#     'book_form_web_view_url': '',
#     'book_again_url': '',
#     'thumb': '',
#     'user_rating': {'aggregate_rating': '4.4',
#      'rating_text': 'Very Good',
#      'rating_color': '5BA829',
#      'rating_obj': {'title': {'text': '4.4'},
#       'bg_color': {'type': 'lime', 'tint': '700'}},
#      'votes': 23244},
#     'all_reviews_count': 365,
#     'photos_url': 'https://www.zomato.com/guwahati/johns-kitchen-christian-basti/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop',
#     'photo_count': 194,
#     'menu_url': 'https://www.zomato.com/guwahati/johns-kitchen-christian-basti/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop',
#     'featured_image': '',
#     'has_online_delivery': 1,
#     'is_delivering_now': 0,
#     'store_type': '',
#     'include_bogo_offers': True,
#     'deeplink': 'zomato://restaurant/2100753',
#     'is_table_reservation_supported': 0,
#     'has_table_booking': 0,
#     'events_url': 'https://www.zomato.com/guwahati/johns-kitchen-christian-basti/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#     'phone_numbers': '+91 9085569216',
#     'all_reviews': {'reviews': [{'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []},
#       {'review': []}]},
#     'establishment': ['Quick Bites'],
#     'establishment_types': []}}]}

# %%
entity_id=4&entity_type=city&start=20&count=50&cuisines=25&sort=rating&order=desc
# Out:
#   File "<ipython-input-11-89e6fdec1e0c>", line 1
#     entity_id=4&entity_type=city&start=20&count=50&cuisines=25&sort=rating&order=desc
#              ^
# SyntaxError: can't assign to operator

# %%
zomato.restaurant_search_by_city(4, "25", 0)

# %%
print("i am inside action_search_restaurants")
# My API Key of Zomato
config = {"user_key":"f9c893da39750138e222b042c8070293"}
zomato = zomatopy.initialize_app(config)

# Price range determination
price = '2'
print(price)
# Get the user selected cuisine
# Slot 'cuisine' would have been updated in the ActionCheckCuisine() with correct cuisine name
cuisine = 'chinese'
print(cuisine)
# Get the user selected location
# Slot 'location' would have been updated in the ActionCheckCity() with correct city name		
loc = 'Bangalore'
print(loc)
# Cuisines code (used by zomato)
# Source: https://developers.zomato.com/documentation?lang=tr#/
cuisines_dict = {'american':1,'chinese':25,'mexican':73,'italian':55,'north indian':50,'south indian':85}

# Prepare the response
response = ""

# As long as there is a valid location specified
if (loc != 'unlisted'):
    # get_location gets the lat-long coordinates of 'loc'
    location_detail = zomato.get_location(loc, 1)
    print(location_detail)
    # Store retrieved data as a dict
    d1 = json.loads(location_detail)
    # Separate lat-long coordinates
    city_id = d1["city_id"]

    # Fetch results
    # If cuisine is specified, then use that to search restaurants
    if (cuisine != 'unlisted'):
        final_results = []
        print(location_detail)
        offset = 0
        for offset in range(0, 1000, 20):
            results = zomato.restaurant_search_by_city(city_id, str(cuisines_dict['chinese']), offset)
    # Cuisine is not specified, hence search for all cuisine types
    else:
        results = zomato.restaurant_search("", lat, lon, 10000)
    d = json.loads(results)
    print(d)
    # Counter to output top 10 results
    count = 0

    # If no results match with the user mentioned criteria
    if d['results_found'] == 0:
        response = "No restaurants found matching your criteria"
        print(response)
    else:           
        response = "Here are the top rated restaurants as per your criteria:"+"\n"

        # Get the restaurants ordered as per their user rating
        for restaurant in d['restaurants']: 

            # Getting Top 10 restaurants for the lower price range
            if ((float(price) == 1) and (restaurant['restaurant']['average_cost_for_two'] < 300) and (count < 10)):
                response = response + restaurant['restaurant']['name']+ " in "+ restaurant['restaurant']['location']['address']+ " has a rating of "+ restaurant['restaurant']['user_rating']['aggregate_rating']+"."
                response = response +" with the average price of Rs."+ str(restaurant['restaurant']['average_cost_for_two'])+ "for two persons" + "\n"
                count = count + 1
                
            # Getting Top 10 restaurants for the mid price range
            elif ((float(price) == 2) and (restaurant['restaurant']['average_cost_for_two'] >= 300) and (restaurant['restaurant']['average_cost_for_two'] <= 700) and (count < 10)):
                response = response + restaurant['restaurant']['name']+ " in "+ restaurant['restaurant']['location']['address']+ " has a rating of "+ restaurant['restaurant']['user_rating']['aggregate_rating']+"\n"
                response = response +" with the average price of Rs."+ str(restaurant['restaurant']['average_cost_for_two'])+ "for two persons" + "\n"
                count = count + 1 

            # Getting Top 10 restaurants for the higher price range                       
            elif ((float(price) == 3) and (restaurant['restaurant']['average_cost_for_two'] > 700) and (count < 10)):
                response = response + restaurant['restaurant']['name']+ " in "+ restaurant['restaurant']['location']['address']+ " has a rating of "+ restaurant['restaurant']['user_rating']['aggregate_rating']+"\n"
                response = response +" with the average price of Rs."+ str(restaurant['restaurant']['average_cost_for_two'])+ "for two persons" + "\n"
                count = count + 1           

    # If no results obtained
    if(count == 0):
        response = "Sorry, No results found for your criteria. Would you like to search for some other restaurants?"
        print(response)
    # Display the results
    else:
        print(response)

# If no valid location is given
else:
    response = "No restaurants found matching your criteria"
    print(response)

# %%
import time
start_time = time.time()
zomatoData = []
for offset in range(0, 80, 20):
        results = zomato.restaurant_search_by_city(4, str(25), offset)
        zomatoData.append(json.loads(results))

print("--- %s seconds ---" % (time.time() - start_time))

# %%
base_url = "https://developers.zomato.com/api/v2.1/"
headers = {'Accept': 'application/json', 'user-key': 'f9c893da39750138e222b042c8070293'}
async with ClientSession() as session:
    async with session.get(base_url + "search?entity_id=" + str(4) + "&entity_type=city" + "&start=" + str(0) + "&cuisines=" + str(25) + "&sort=rating&order=desc", headers=headers) as response:
        response = await response.read()
        r = (response.decode("utf-8"))

# %%
import asyncio
from aiohttp import ClientSession

async def hello(url):
    async with ClientSession() as session:
        async with session.get(url) as response:
            response = await response.read()
            print(response)

loop = asyncio.get_event_loop()

# %%
loop = asyncio.get_event_loop()

if loop.is_running() == False:
    val = asyncio.run(hello("http://httpbin.org/headers"))
else:
    val = await hello("http://httpbin.org/headers")
abc = json.loads(val)
print(abc)

# %%
import time

# %%
import asyncio
from aiohttp import ClientSession
base_url = "https://developers.zomato.com/api/v2.1/"
headers = {'Accept': 'application/json', 'user-key': 'f9c893da39750138e222b042c8070293'}
start_time = time.time()
for offset in range(0, 500, 20):
    async with ClientSession() as session:
    async with session.get(base_url + "search?entity_id=" + str(4) + "&entity_type=city" + "&start=" + str(0) + "&cuisines=" + str(25) + "&sort=rating&order=desc", headers=headers) as response:
        response = await response.read()
        r = (response.decode("utf-8"))
    loop = asyncio.get_event_loop()
    if loop.is_running() == False:
        results = asyncio.run(zomato.restaurant_search_by_city_async(4, str(25), 0))
    else:
        results = await zomato.restaurant_search_by_city_async(4, str(25), 0)
    d1 = json.loads(results)
    print(d1)
print("--- %s seconds ---" % (time.time() - start_time))
print(offset)
# Out:
# {'results_found': 7241, 'results_start': 0, 'results_shown': 20, 'restaurants': [{'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1}, 'res_id': 51040, 'is_grocery_store': False}, 'apikey': 'f9c893da39750138e222b042c8070293', 'id': '51040', 'name': 'Truffles', 'url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'location': {'address': '28, 4th B Cross, Koramangala 5th Block, Bangalore', 'locality': 'Koramangala 5th Block', 'city': 'Bangalore', 'city_id': 4, 'latitude': '12.9334920681', 'longitude': '77.6143708080', 'zipcode': '0', 'country_id': 1, 'locality_verbose': 'Koramangala 5th Block, Bangalore'}, 'switch_to_order_menu': 0, 'cuisines': 'Cafe, American, Burger, Steak', 'timings': '12noon – 3:30pm, 7pm – 10:30pm (Mon),12noon – 10:30pm (Tue-Sun)', 'average_cost_for_two': 900, 'price_range': 2, 'currency': 'Rs.', 'highlights': ['Dinner', 'Takeaway Available', 'Debit Card', 'Lunch', 'Cash', 'Credit Card', 'Indoor Seating', 'Air Conditioned', 'Digital Payments Accepted'], 'offers': [], 'opentable_support': 0, 'is_zomato_book_res': 0, 'mezzo_provider': 'OTHER', 'is_book_form_web_view': 0, 'book_form_web_view_url': '', 'book_again_url': '', 'thumb': 'https://b.zmtcdn.com/data/pictures/chains/8/51038/c312bf371d4e0aea2021a1fd824054ed.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A', 'user_rating': {'aggregate_rating': '4.8', 'rating_text': 'Excellent', 'rating_color': '3F7E00', 'rating_obj': {'title': {'text': '4.8'}, 'bg_color': {'type': 'lime', 'tint': '800'}}, 'votes': 16587}, 'all_reviews_count': 7357, 'photos_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop', 'photo_count': 12504, 'menu_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop', 'featured_image': 'https://b.zmtcdn.com/data/pictures/chains/8/51038/c312bf371d4e0aea2021a1fd824054ed.jpg', 'has_online_delivery': 0, 'is_delivering_now': 0, 'store_type': '', 'include_bogo_offers': True, 'deeplink': 'zomato://restaurant/51040', 'is_table_reservation_supported': 0, 'has_table_booking': 0, 'events_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'phone_numbers': '080 41466565, 080 41536565', 'all_reviews': {'reviews': [{'review': []}, {'review': []}, {'review': []}, {'review': []}, {'review': []}]}, 'establishment': ['Café'], 'establishment_types': []}}, {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1}, 'res_id': 18430785, 'is_grocery_store': False}, 'apikey': 'f9c893da39750138e222b042c8070293', 'id': '18430785', 'name': 'Communiti', 'url': 'https://www.zomato.com/bangalore/communiti-residency-road?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'location': {'address': '67 & 68, Brigade Solitaire, Opposite Advaith Hyundai, Residency Road, Bangalore', 'locality': 'Residency Road', 'city': 'Bangalore', 'city_id': 4, 'latitude': '12.9722191879', 'longitude': '77.6083690301', 'zipcode': '560025', 'country_id': 1, 'locality_verbose': 'Residency Road, Bangalore'}, 'switch_to_order_menu': 0, 'cuisines': 'Continental, BBQ', 'timings': '11:30am – 1am (Mon-Sun)', 'average_cost_for_two': 1500, 'price_range': 3, 'currency': 'Rs.', 'highlights': ['Dinner', 'Takeaway Available', 'Breakfast', 'Lunch', 'Cash', 'Credit Card', 'Debit Card', 'Valet Parking Available', 'Fullbar', 'Indoor Seating', 'Air Conditioned', 'Pet Friendly', 'Craft Beer', 'Outdoor Seating', 'Table booking recommended', 'Smoking Area'], 'offers': [], 'opentable_support': 0, 'is_zomato_book_res': 0, 'mezzo_provider': 'OTHER', 'is_book_form_web_view': 0, 'book_form_web_view_url': '', 'book_again_url': '', 'thumb': 'https://b.zmtcdn.com/data/pictures/5/18430785/21a5bfcd5075 ...
# {'results_found': 7242, 'results_start': 0, 'results_shown': 20, 'restaurants': [{'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1}, 'res_id': 51040, 'is_grocery_store': False}, 'apikey': 'f9c893da39750138e222b042c8070293', 'id': '51040', 'name': 'Truffles', 'url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'location': {'address': '28, 4th B Cross, Koramangala 5th Block, Bangalore', 'locality': 'Koramangala 5th Block', 'city': 'Bangalore', 'city_id': 4, 'latitude': '12.9334920681', 'longitude': '77.6143708080', 'zipcode': '0', 'country_id': 1, 'locality_verbose': 'Koramangala 5th Block, Bangalore'}, 'switch_to_order_menu': 0, 'cuisines': 'Cafe, American, Burger, Steak', 'timings': '12noon – 3:30pm, 7pm – 10:30pm (Mon),12noon – 10:30pm (Tue-Sun)', 'average_cost_for_two': 900, 'price_range': 2, 'currency': 'Rs.', 'highlights': ['Dinner', 'Takeaway Available', 'Debit Card', 'Lunch', 'Cash', 'Credit Card', 'Indoor Seating', 'Air Conditioned', 'Digital Payments Accepted'], 'offers': [], 'opentable_support': 0, 'is_zomato_book_res': 0, 'mezzo_provider': 'OTHER', 'is_book_form_web_view': 0, 'book_form_web_view_url': '', 'book_again_url': '', 'thumb': 'https://b.zmtcdn.com/data/pictures/chains/8/51038/c312bf371d4e0aea2021a1fd824054ed.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A', 'user_rating': {'aggregate_rating': '4.8', 'rating_text': 'Excellent', 'rating_color': '3F7E00', 'rating_obj': {'title': {'text': '4.8'}, 'bg_color': {'type': 'lime', 'tint': '800'}}, 'votes': 16587}, 'all_reviews_count': 7357, 'photos_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop', 'photo_count': 12504, 'menu_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop', 'featured_image': 'https://b.zmtcdn.com/data/pictures/chains/8/51038/c312bf371d4e0aea2021a1fd824054ed.jpg', 'has_online_delivery': 0, 'is_delivering_now': 0, 'store_type': '', 'include_bogo_offers': True, 'deeplink': 'zomato://restaurant/51040', 'is_table_reservation_supported': 0, 'has_table_booking': 0, 'events_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'phone_numbers': '080 41466565, 080 41536565', 'all_reviews': {'reviews': [{'review': []}, {'review': []}, {'review': []}, {'review': []}, {'review': []}]}, 'establishment': ['Café'], 'establishment_types': []}}, {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1}, 'res_id': 18430785, 'is_grocery_store': False}, 'apikey': 'f9c893da39750138e222b042c8070293', 'id': '18430785', 'name': 'Communiti', 'url': 'https://www.zomato.com/bangalore/communiti-residency-road?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'location': {'address': '67 & 68, Brigade Solitaire, Opposite Advaith Hyundai, Residency Road, Bangalore', 'locality': 'Residency Road', 'city': 'Bangalore', 'city_id': 4, 'latitude': '12.9722191879', 'longitude': '77.6083690301', 'zipcode': '560025', 'country_id': 1, 'locality_verbose': 'Residency Road, Bangalore'}, 'switch_to_order_menu': 0, 'cuisines': 'Continental, BBQ', 'timings': '11:30am – 1am (Mon-Sun)', 'average_cost_for_two': 1500, 'price_range': 3, 'currency': 'Rs.', 'highlights': ['Dinner', 'Takeaway Available', 'Breakfast', 'Lunch', 'Cash', 'Credit Card', 'Debit Card', 'Valet Parking Available', 'Fullbar', 'Indoor Seating', 'Air Conditioned', 'Pet Friendly', 'Craft Beer', 'Outdoor Seating', 'Table booking recommended', 'Smoking Area'], 'offers': [], 'opentable_support': 0, 'is_zomato_book_res': 0, 'mezzo_provider': 'OTHER', 'is_book_form_web_view': 0, 'book_form_web_view_url': '', 'book_again_url': '', 'thumb': 'https://b.zmtcdn.com/data/pictures/5/18430785/21a5bfcd5075 ...
# {'results_found': 7242, 'results_start': 0, 'results_shown': 20, 'restaurants': [{'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1}, 'res_id': 51040, 'is_grocery_store': False}, 'apikey': 'f9c893da39750138e222b042c8070293', 'id': '51040', 'name': 'Truffles', 'url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'location': {'address': '28, 4th B Cross, Koramangala 5th Block, Bangalore', 'locality': 'Koramangala 5th Block', 'city': 'Bangalore', 'city_id': 4, 'latitude': '12.9334920681', 'longitude': '77.6143708080', 'zipcode': '0', 'country_id': 1, 'locality_verbose': 'Koramangala 5th Block, Bangalore'}, 'switch_to_order_menu': 0, 'cuisines': 'Cafe, American, Burger, Steak', 'timings': '12noon – 3:30pm, 7pm – 10:30pm (Mon),12noon – 10:30pm (Tue-Sun)', 'average_cost_for_two': 900, 'price_range': 2, 'currency': 'Rs.', 'highlights': ['Dinner', 'Takeaway Available', 'Debit Card', 'Lunch', 'Cash', 'Credit Card', 'Indoor Seating', 'Air Conditioned', 'Digital Payments Accepted'], 'offers': [], 'opentable_support': 0, 'is_zomato_book_res': 0, 'mezzo_provider': 'OTHER', 'is_book_form_web_view': 0, 'book_form_web_view_url': '', 'book_again_url': '', 'thumb': 'https://b.zmtcdn.com/data/pictures/chains/8/51038/c312bf371d4e0aea2021a1fd824054ed.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A', 'user_rating': {'aggregate_rating': '4.8', 'rating_text': 'Excellent', 'rating_color': '3F7E00', 'rating_obj': {'title': {'text': '4.8'}, 'bg_color': {'type': 'lime', 'tint': '800'}}, 'votes': 16587}, 'all_reviews_count': 7357, 'photos_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop', 'photo_count': 12504, 'menu_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop', 'featured_image': 'https://b.zmtcdn.com/data/pictures/chains/8/51038/c312bf371d4e0aea2021a1fd824054ed.jpg', 'has_online_delivery': 0, 'is_delivering_now': 0, 'store_type': '', 'include_bogo_offers': True, 'deeplink': 'zomato://restaurant/51040', 'is_table_reservation_supported': 0, 'has_table_booking': 0, 'events_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'phone_numbers': '080 41466565, 080 41536565', 'all_reviews': {'reviews': [{'review': []}, {'review': []}, {'review': []}, {'review': []}, {'review': []}]}, 'establishment': ['Café'], 'establishment_types': []}}, {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1}, 'res_id': 18430785, 'is_grocery_store': False}, 'apikey': 'f9c893da39750138e222b042c8070293', 'id': '18430785', 'name': 'Communiti', 'url': 'https://www.zomato.com/bangalore/communiti-residency-road?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'location': {'address': '67 & 68, Brigade Solitaire, Opposite Advaith Hyundai, Residency Road, Bangalore', 'locality': 'Residency Road', 'city': 'Bangalore', 'city_id': 4, 'latitude': '12.9722191879', 'longitude': '77.6083690301', 'zipcode': '560025', 'country_id': 1, 'locality_verbose': 'Residency Road, Bangalore'}, 'switch_to_order_menu': 0, 'cuisines': 'Continental, BBQ', 'timings': '11:30am – 1am (Mon-Sun)', 'average_cost_for_two': 1500, 'price_range': 3, 'currency': 'Rs.', 'highlights': ['Dinner', 'Takeaway Available', 'Breakfast', 'Lunch', 'Cash', 'Credit Card', 'Debit Card', 'Valet Parking Available', 'Fullbar', 'Indoor Seating', 'Air Conditioned', 'Pet Friendly', 'Craft Beer', 'Outdoor Seating', 'Table booking recommended', 'Smoking Area'], 'offers': [], 'opentable_support': 0, 'is_zomato_book_res': 0, 'mezzo_provider': 'OTHER', 'is_book_form_web_view': 0, 'book_form_web_view_url': '', 'book_again_url': '', 'thumb': 'https://b.zmtcdn.com/data/pictures/5/18430785/21a5bfcd5075 ...
# {'results_found': 7242, 'results_start': 0, 'results_shown': 20, 'restaurants': [{'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1}, 'res_id': 51040, 'is_grocery_store': False}, 'apikey': 'f9c893da39750138e222b042c8070293', 'id': '51040', 'name': 'Truffles', 'url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'location': {'address': '28, 4th B Cross, Koramangala 5th Block, Bangalore', 'locality': 'Koramangala 5th Block', 'city': 'Bangalore', 'city_id': 4, 'latitude': '12.9334920681', 'longitude': '77.6143708080', 'zipcode': '0', 'country_id': 1, 'locality_verbose': 'Koramangala 5th Block, Bangalore'}, 'switch_to_order_menu': 0, 'cuisines': 'Cafe, American, Burger, Steak', 'timings': '12noon – 3:30pm, 7pm – 10:30pm (Mon),12noon – 10:30pm (Tue-Sun)', 'average_cost_for_two': 900, 'price_range': 2, 'currency': 'Rs.', 'highlights': ['Dinner', 'Takeaway Available', 'Debit Card', 'Lunch', 'Cash', 'Credit Card', 'Indoor Seating', 'Air Conditioned', 'Digital Payments Accepted'], 'offers': [], 'opentable_support': 0, 'is_zomato_book_res': 0, 'mezzo_provider': 'OTHER', 'is_book_form_web_view': 0, 'book_form_web_view_url': '', 'book_again_url': '', 'thumb': 'https://b.zmtcdn.com/data/pictures/chains/8/51038/c312bf371d4e0aea2021a1fd824054ed.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A', 'user_rating': {'aggregate_rating': '4.8', 'rating_text': 'Excellent', 'rating_color': '3F7E00', 'rating_obj': {'title': {'text': '4.8'}, 'bg_color': {'type': 'lime', 'tint': '800'}}, 'votes': 16587}, 'all_reviews_count': 7357, 'photos_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop', 'photo_count': 12504, 'menu_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop', 'featured_image': 'https://b.zmtcdn.com/data/pictures/chains/8/51038/c312bf371d4e0aea2021a1fd824054ed.jpg', 'has_online_delivery': 0, 'is_delivering_now': 0, 'store_type': '', 'include_bogo_offers': True, 'deeplink': 'zomato://restaurant/51040', 'is_table_reservation_supported': 0, 'has_table_booking': 0, 'events_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'phone_numbers': '080 41466565, 080 41536565', 'all_reviews': {'reviews': [{'review': []}, {'review': []}, {'review': []}, {'review': []}, {'review': []}]}, 'establishment': ['Café'], 'establishment_types': []}}, {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1}, 'res_id': 18430785, 'is_grocery_store': False}, 'apikey': 'f9c893da39750138e222b042c8070293', 'id': '18430785', 'name': 'Communiti', 'url': 'https://www.zomato.com/bangalore/communiti-residency-road?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'location': {'address': '67 & 68, Brigade Solitaire, Opposite Advaith Hyundai, Residency Road, Bangalore', 'locality': 'Residency Road', 'city': 'Bangalore', 'city_id': 4, 'latitude': '12.9722191879', 'longitude': '77.6083690301', 'zipcode': '560025', 'country_id': 1, 'locality_verbose': 'Residency Road, Bangalore'}, 'switch_to_order_menu': 0, 'cuisines': 'Continental, BBQ', 'timings': '11:30am – 1am (Mon-Sun)', 'average_cost_for_two': 1500, 'price_range': 3, 'currency': 'Rs.', 'highlights': ['Dinner', 'Takeaway Available', 'Breakfast', 'Lunch', 'Cash', 'Credit Card', 'Debit Card', 'Valet Parking Available', 'Fullbar', 'Indoor Seating', 'Air Conditioned', 'Pet Friendly', 'Craft Beer', 'Outdoor Seating', 'Table booking recommended', 'Smoking Area'], 'offers': [], 'opentable_support': 0, 'is_zomato_book_res': 0, 'mezzo_provider': 'OTHER', 'is_book_form_web_view': 0, 'book_form_web_view_url': '', 'book_again_url': '', 'thumb': 'https://b.zmtcdn.com/data/pictures/5/18430785/21a5bfcd5075 ...
# {'results_found': 7242, 'results_start': 0, 'results_shown': 20, 'restaurants': [{'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1}, 'res_id': 51040, 'is_grocery_store': False}, 'apikey': 'f9c893da39750138e222b042c8070293', 'id': '51040', 'name': 'Truffles', 'url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'location': {'address': '28, 4th B Cross, Koramangala 5th Block, Bangalore', 'locality': 'Koramangala 5th Block', 'city': 'Bangalore', 'city_id': 4, 'latitude': '12.9334920681', 'longitude': '77.6143708080', 'zipcode': '0', 'country_id': 1, 'locality_verbose': 'Koramangala 5th Block, Bangalore'}, 'switch_to_order_menu': 0, 'cuisines': 'Cafe, American, Burger, Steak', 'timings': '12noon – 3:30pm, 7pm – 10:30pm (Mon),12noon – 10:30pm (Tue-Sun)', 'average_cost_for_two': 900, 'price_range': 2, 'currency': 'Rs.', 'highlights': ['Dinner', 'Takeaway Available', 'Debit Card', 'Lunch', 'Cash', 'Credit Card', 'Indoor Seating', 'Air Conditioned', 'Digital Payments Accepted'], 'offers': [], 'opentable_support': 0, 'is_zomato_book_res': 0, 'mezzo_provider': 'OTHER', 'is_book_form_web_view': 0, 'book_form_web_view_url': '', 'book_again_url': '', 'thumb': 'https://b.zmtcdn.com/data/pictures/chains/8/51038/c312bf371d4e0aea2021a1fd824054ed.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A', 'user_rating': {'aggregate_rating': '4.8', 'rating_text': 'Excellent', 'rating_color': '3F7E00', 'rating_obj': {'title': {'text': '4.8'}, 'bg_color': {'type': 'lime', 'tint': '800'}}, 'votes': 16587}, 'all_reviews_count': 7357, 'photos_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop', 'photo_count': 12504, 'menu_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop', 'featured_image': 'https://b.zmtcdn.com/data/pictures/chains/8/51038/c312bf371d4e0aea2021a1fd824054ed.jpg', 'has_online_delivery': 0, 'is_delivering_now': 0, 'store_type': '', 'include_bogo_offers': True, 'deeplink': 'zomato://restaurant/51040', 'is_table_reservation_supported': 0, 'has_table_booking': 0, 'events_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'phone_numbers': '080 41466565, 080 41536565', 'all_reviews': {'reviews': [{'review': []}, {'review': []}, {'review': []}, {'review': []}, {'review': []}]}, 'establishment': ['Café'], 'establishment_types': []}}, {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1}, 'res_id': 18430785, 'is_grocery_store': False}, 'apikey': 'f9c893da39750138e222b042c8070293', 'id': '18430785', 'name': 'Communiti', 'url': 'https://www.zomato.com/bangalore/communiti-residency-road?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'location': {'address': '67 & 68, Brigade Solitaire, Opposite Advaith Hyundai, Residency Road, Bangalore', 'locality': 'Residency Road', 'city': 'Bangalore', 'city_id': 4, 'latitude': '12.9722191879', 'longitude': '77.6083690301', 'zipcode': '560025', 'country_id': 1, 'locality_verbose': 'Residency Road, Bangalore'}, 'switch_to_order_menu': 0, 'cuisines': 'Continental, BBQ', 'timings': '11:30am – 1am (Mon-Sun)', 'average_cost_for_two': 1500, 'price_range': 3, 'currency': 'Rs.', 'highlights': ['Dinner', 'Takeaway Available', 'Breakfast', 'Lunch', 'Cash', 'Credit Card', 'Debit Card', 'Valet Parking Available', 'Fullbar', 'Indoor Seating', 'Air Conditioned', 'Pet Friendly', 'Craft Beer', 'Outdoor Seating', 'Table booking recommended', 'Smoking Area'], 'offers': [], 'opentable_support': 0, 'is_zomato_book_res': 0, 'mezzo_provider': 'OTHER', 'is_book_form_web_view': 0, 'book_form_web_view_url': '', 'book_again_url': '', 'thumb': 'https://b.zmtcdn.com/data/pictures/5/18430785/21a5bfcd5075 ...
# {'results_found': 7241, 'results_start': 0, 'results_shown': 20, 'restaurants': [{'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1}, 'res_id': 51040, 'is_grocery_store': False}, 'apikey': 'f9c893da39750138e222b042c8070293', 'id': '51040', 'name': 'Truffles', 'url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'location': {'address': '28, 4th B Cross, Koramangala 5th Block, Bangalore', 'locality': 'Koramangala 5th Block', 'city': 'Bangalore', 'city_id': 4, 'latitude': '12.9334920681', 'longitude': '77.6143708080', 'zipcode': '0', 'country_id': 1, 'locality_verbose': 'Koramangala 5th Block, Bangalore'}, 'switch_to_order_menu': 0, 'cuisines': 'Cafe, American, Burger, Steak', 'timings': '12noon – 3:30pm, 7pm – 10:30pm (Mon),12noon – 10:30pm (Tue-Sun)', 'average_cost_for_two': 900, 'price_range': 2, 'currency': 'Rs.', 'highlights': ['Dinner', 'Takeaway Available', 'Debit Card', 'Lunch', 'Cash', 'Credit Card', 'Indoor Seating', 'Air Conditioned', 'Digital Payments Accepted'], 'offers': [], 'opentable_support': 0, 'is_zomato_book_res': 0, 'mezzo_provider': 'OTHER', 'is_book_form_web_view': 0, 'book_form_web_view_url': '', 'book_again_url': '', 'thumb': 'https://b.zmtcdn.com/data/pictures/chains/8/51038/c312bf371d4e0aea2021a1fd824054ed.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A', 'user_rating': {'aggregate_rating': '4.8', 'rating_text': 'Excellent', 'rating_color': '3F7E00', 'rating_obj': {'title': {'text': '4.8'}, 'bg_color': {'type': 'lime', 'tint': '800'}}, 'votes': 16587}, 'all_reviews_count': 7357, 'photos_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop', 'photo_count': 12504, 'menu_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop', 'featured_image': 'https://b.zmtcdn.com/data/pictures/chains/8/51038/c312bf371d4e0aea2021a1fd824054ed.jpg', 'has_online_delivery': 0, 'is_delivering_now': 0, 'store_type': '', 'include_bogo_offers': True, 'deeplink': 'zomato://restaurant/51040', 'is_table_reservation_supported': 0, 'has_table_booking': 0, 'events_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'phone_numbers': '080 41466565, 080 41536565', 'all_reviews': {'reviews': [{'review': []}, {'review': []}, {'review': []}, {'review': []}, {'review': []}]}, 'establishment': ['Café'], 'establishment_types': []}}, {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1}, 'res_id': 18430785, 'is_grocery_store': False}, 'apikey': 'f9c893da39750138e222b042c8070293', 'id': '18430785', 'name': 'Communiti', 'url': 'https://www.zomato.com/bangalore/communiti-residency-road?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'location': {'address': '67 & 68, Brigade Solitaire, Opposite Advaith Hyundai, Residency Road, Bangalore', 'locality': 'Residency Road', 'city': 'Bangalore', 'city_id': 4, 'latitude': '12.9722191879', 'longitude': '77.6083690301', 'zipcode': '560025', 'country_id': 1, 'locality_verbose': 'Residency Road, Bangalore'}, 'switch_to_order_menu': 0, 'cuisines': 'Continental, BBQ', 'timings': '11:30am – 1am (Mon-Sun)', 'average_cost_for_two': 1500, 'price_range': 3, 'currency': 'Rs.', 'highlights': ['Dinner', 'Takeaway Available', 'Breakfast', 'Lunch', 'Cash', 'Credit Card', 'Debit Card', 'Valet Parking Available', 'Fullbar', 'Indoor Seating', 'Air Conditioned', 'Pet Friendly', 'Craft Beer', 'Outdoor Seating', 'Table booking recommended', 'Smoking Area'], 'offers': [], 'opentable_support': 0, 'is_zomato_book_res': 0, 'mezzo_provider': 'OTHER', 'is_book_form_web_view': 0, 'book_form_web_view_url': '', 'book_again_url': '', 'thumb': 'https://b.zmtcdn.com/data/pictures/5/18430785/21a5bfcd5075 ...
# {'results_found': 7242, 'results_start': 0, 'results_shown': 20, 'restaurants': [{'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1}, 'res_id': 51040, 'is_grocery_store': False}, 'apikey': 'f9c893da39750138e222b042c8070293', 'id': '51040', 'name': 'Truffles', 'url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'location': {'address': '28, 4th B Cross, Koramangala 5th Block, Bangalore', 'locality': 'Koramangala 5th Block', 'city': 'Bangalore', 'city_id': 4, 'latitude': '12.9334920681', 'longitude': '77.6143708080', 'zipcode': '0', 'country_id': 1, 'locality_verbose': 'Koramangala 5th Block, Bangalore'}, 'switch_to_order_menu': 0, 'cuisines': 'Cafe, American, Burger, Steak', 'timings': '12noon – 3:30pm, 7pm – 10:30pm (Mon),12noon – 10:30pm (Tue-Sun)', 'average_cost_for_two': 900, 'price_range': 2, 'currency': 'Rs.', 'highlights': ['Dinner', 'Takeaway Available', 'Debit Card', 'Lunch', 'Cash', 'Credit Card', 'Indoor Seating', 'Air Conditioned', 'Digital Payments Accepted'], 'offers': [], 'opentable_support': 0, 'is_zomato_book_res': 0, 'mezzo_provider': 'OTHER', 'is_book_form_web_view': 0, 'book_form_web_view_url': '', 'book_again_url': '', 'thumb': 'https://b.zmtcdn.com/data/pictures/chains/8/51038/c312bf371d4e0aea2021a1fd824054ed.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A', 'user_rating': {'aggregate_rating': '4.8', 'rating_text': 'Excellent', 'rating_color': '3F7E00', 'rating_obj': {'title': {'text': '4.8'}, 'bg_color': {'type': 'lime', 'tint': '800'}}, 'votes': 16587}, 'all_reviews_count': 7357, 'photos_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop', 'photo_count': 12504, 'menu_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop', 'featured_image': 'https://b.zmtcdn.com/data/pictures/chains/8/51038/c312bf371d4e0aea2021a1fd824054ed.jpg', 'has_online_delivery': 0, 'is_delivering_now': 0, 'store_type': '', 'include_bogo_offers': True, 'deeplink': 'zomato://restaurant/51040', 'is_table_reservation_supported': 0, 'has_table_booking': 0, 'events_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'phone_numbers': '080 41466565, 080 41536565', 'all_reviews': {'reviews': [{'review': []}, {'review': []}, {'review': []}, {'review': []}, {'review': []}]}, 'establishment': ['Café'], 'establishment_types': []}}, {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1}, 'res_id': 18430785, 'is_grocery_store': False}, 'apikey': 'f9c893da39750138e222b042c8070293', 'id': '18430785', 'name': 'Communiti', 'url': 'https://www.zomato.com/bangalore/communiti-residency-road?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'location': {'address': '67 & 68, Brigade Solitaire, Opposite Advaith Hyundai, Residency Road, Bangalore', 'locality': 'Residency Road', 'city': 'Bangalore', 'city_id': 4, 'latitude': '12.9722191879', 'longitude': '77.6083690301', 'zipcode': '560025', 'country_id': 1, 'locality_verbose': 'Residency Road, Bangalore'}, 'switch_to_order_menu': 0, 'cuisines': 'Continental, BBQ', 'timings': '11:30am – 1am (Mon-Sun)', 'average_cost_for_two': 1500, 'price_range': 3, 'currency': 'Rs.', 'highlights': ['Dinner', 'Takeaway Available', 'Breakfast', 'Lunch', 'Cash', 'Credit Card', 'Debit Card', 'Valet Parking Available', 'Fullbar', 'Indoor Seating', 'Air Conditioned', 'Pet Friendly', 'Craft Beer', 'Outdoor Seating', 'Table booking recommended', 'Smoking Area'], 'offers': [], 'opentable_support': 0, 'is_zomato_book_res': 0, 'mezzo_provider': 'OTHER', 'is_book_form_web_view': 0, 'book_form_web_view_url': '', 'book_again_url': '', 'thumb': 'https://b.zmtcdn.com/data/pictures/5/18430785/21a5bfcd5075 ...
# {'results_found': 7242, 'results_start': 0, 'results_shown': 20, 'restaurants': [{'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1}, 'res_id': 51040, 'is_grocery_store': False}, 'apikey': 'f9c893da39750138e222b042c8070293', 'id': '51040', 'name': 'Truffles', 'url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'location': {'address': '28, 4th B Cross, Koramangala 5th Block, Bangalore', 'locality': 'Koramangala 5th Block', 'city': 'Bangalore', 'city_id': 4, 'latitude': '12.9334920681', 'longitude': '77.6143708080', 'zipcode': '0', 'country_id': 1, 'locality_verbose': 'Koramangala 5th Block, Bangalore'}, 'switch_to_order_menu': 0, 'cuisines': 'Cafe, American, Burger, Steak', 'timings': '12noon – 3:30pm, 7pm – 10:30pm (Mon),12noon – 10:30pm (Tue-Sun)', 'average_cost_for_two': 900, 'price_range': 2, 'currency': 'Rs.', 'highlights': ['Dinner', 'Takeaway Available', 'Debit Card', 'Lunch', 'Cash', 'Credit Card', 'Indoor Seating', 'Air Conditioned', 'Digital Payments Accepted'], 'offers': [], 'opentable_support': 0, 'is_zomato_book_res': 0, 'mezzo_provider': 'OTHER', 'is_book_form_web_view': 0, 'book_form_web_view_url': '', 'book_again_url': '', 'thumb': 'https://b.zmtcdn.com/data/pictures/chains/8/51038/c312bf371d4e0aea2021a1fd824054ed.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A', 'user_rating': {'aggregate_rating': '4.8', 'rating_text': 'Excellent', 'rating_color': '3F7E00', 'rating_obj': {'title': {'text': '4.8'}, 'bg_color': {'type': 'lime', 'tint': '800'}}, 'votes': 16587}, 'all_reviews_count': 7357, 'photos_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop', 'photo_count': 12504, 'menu_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop', 'featured_image': 'https://b.zmtcdn.com/data/pictures/chains/8/51038/c312bf371d4e0aea2021a1fd824054ed.jpg', 'has_online_delivery': 0, 'is_delivering_now': 0, 'store_type': '', 'include_bogo_offers': True, 'deeplink': 'zomato://restaurant/51040', 'is_table_reservation_supported': 0, 'has_table_booking': 0, 'events_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'phone_numbers': '080 41466565, 080 41536565', 'all_reviews': {'reviews': [{'review': []}, {'review': []}, {'review': []}, {'review': []}, {'review': []}]}, 'establishment': ['Café'], 'establishment_types': []}}, {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1}, 'res_id': 18430785, 'is_grocery_store': False}, 'apikey': 'f9c893da39750138e222b042c8070293', 'id': '18430785', 'name': 'Communiti', 'url': 'https://www.zomato.com/bangalore/communiti-residency-road?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'location': {'address': '67 & 68, Brigade Solitaire, Opposite Advaith Hyundai, Residency Road, Bangalore', 'locality': 'Residency Road', 'city': 'Bangalore', 'city_id': 4, 'latitude': '12.9722191879', 'longitude': '77.6083690301', 'zipcode': '560025', 'country_id': 1, 'locality_verbose': 'Residency Road, Bangalore'}, 'switch_to_order_menu': 0, 'cuisines': 'Continental, BBQ', 'timings': '11:30am – 1am (Mon-Sun)', 'average_cost_for_two': 1500, 'price_range': 3, 'currency': 'Rs.', 'highlights': ['Dinner', 'Takeaway Available', 'Breakfast', 'Lunch', 'Cash', 'Credit Card', 'Debit Card', 'Valet Parking Available', 'Fullbar', 'Indoor Seating', 'Air Conditioned', 'Pet Friendly', 'Craft Beer', 'Outdoor Seating', 'Table booking recommended', 'Smoking Area'], 'offers': [], 'opentable_support': 0, 'is_zomato_book_res': 0, 'mezzo_provider': 'OTHER', 'is_book_form_web_view': 0, 'book_form_web_view_url': '', 'book_again_url': '', 'thumb': 'https://b.zmtcdn.com/data/pictures/5/18430785/21a5bfcd5075 ...
# {'results_found': 7241, 'results_start': 0, 'results_shown': 20, 'restaurants': [{'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1}, 'res_id': 51040, 'is_grocery_store': False}, 'apikey': 'f9c893da39750138e222b042c8070293', 'id': '51040', 'name': 'Truffles', 'url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'location': {'address': '28, 4th B Cross, Koramangala 5th Block, Bangalore', 'locality': 'Koramangala 5th Block', 'city': 'Bangalore', 'city_id': 4, 'latitude': '12.9334920681', 'longitude': '77.6143708080', 'zipcode': '0', 'country_id': 1, 'locality_verbose': 'Koramangala 5th Block, Bangalore'}, 'switch_to_order_menu': 0, 'cuisines': 'Cafe, American, Burger, Steak', 'timings': '12noon – 3:30pm, 7pm – 10:30pm (Mon),12noon – 10:30pm (Tue-Sun)', 'average_cost_for_two': 900, 'price_range': 2, 'currency': 'Rs.', 'highlights': ['Dinner', 'Takeaway Available', 'Debit Card', 'Lunch', 'Cash', 'Credit Card', 'Indoor Seating', 'Air Conditioned', 'Digital Payments Accepted'], 'offers': [], 'opentable_support': 0, 'is_zomato_book_res': 0, 'mezzo_provider': 'OTHER', 'is_book_form_web_view': 0, 'book_form_web_view_url': '', 'book_again_url': '', 'thumb': 'https://b.zmtcdn.com/data/pictures/chains/8/51038/c312bf371d4e0aea2021a1fd824054ed.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A', 'user_rating': {'aggregate_rating': '4.8', 'rating_text': 'Excellent', 'rating_color': '3F7E00', 'rating_obj': {'title': {'text': '4.8'}, 'bg_color': {'type': 'lime', 'tint': '800'}}, 'votes': 16587}, 'all_reviews_count': 7357, 'photos_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop', 'photo_count': 12504, 'menu_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop', 'featured_image': 'https://b.zmtcdn.com/data/pictures/chains/8/51038/c312bf371d4e0aea2021a1fd824054ed.jpg', 'has_online_delivery': 0, 'is_delivering_now': 0, 'store_type': '', 'include_bogo_offers': True, 'deeplink': 'zomato://restaurant/51040', 'is_table_reservation_supported': 0, 'has_table_booking': 0, 'events_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'phone_numbers': '080 41466565, 080 41536565', 'all_reviews': {'reviews': [{'review': []}, {'review': []}, {'review': []}, {'review': []}, {'review': []}]}, 'establishment': ['Café'], 'establishment_types': []}}, {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1}, 'res_id': 18430785, 'is_grocery_store': False}, 'apikey': 'f9c893da39750138e222b042c8070293', 'id': '18430785', 'name': 'Communiti', 'url': 'https://www.zomato.com/bangalore/communiti-residency-road?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'location': {'address': '67 & 68, Brigade Solitaire, Opposite Advaith Hyundai, Residency Road, Bangalore', 'locality': 'Residency Road', 'city': 'Bangalore', 'city_id': 4, 'latitude': '12.9722191879', 'longitude': '77.6083690301', 'zipcode': '560025', 'country_id': 1, 'locality_verbose': 'Residency Road, Bangalore'}, 'switch_to_order_menu': 0, 'cuisines': 'Continental, BBQ', 'timings': '11:30am – 1am (Mon-Sun)', 'average_cost_for_two': 1500, 'price_range': 3, 'currency': 'Rs.', 'highlights': ['Dinner', 'Takeaway Available', 'Breakfast', 'Lunch', 'Cash', 'Credit Card', 'Debit Card', 'Valet Parking Available', 'Fullbar', 'Indoor Seating', 'Air Conditioned', 'Pet Friendly', 'Craft Beer', 'Outdoor Seating', 'Table booking recommended', 'Smoking Area'], 'offers': [], 'opentable_support': 0, 'is_zomato_book_res': 0, 'mezzo_provider': 'OTHER', 'is_book_form_web_view': 0, 'book_form_web_view_url': '', 'book_again_url': '', 'thumb': 'https://b.zmtcdn.com/data/pictures/5/18430785/21a5bfcd5075 ...
# {'results_found': 7241, 'results_start': 0, 'results_shown': 20, 'restaurants': [{'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1}, 'res_id': 51040, 'is_grocery_store': False}, 'apikey': 'f9c893da39750138e222b042c8070293', 'id': '51040', 'name': 'Truffles', 'url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'location': {'address': '28, 4th B Cross, Koramangala 5th Block, Bangalore', 'locality': 'Koramangala 5th Block', 'city': 'Bangalore', 'city_id': 4, 'latitude': '12.9334920681', 'longitude': '77.6143708080', 'zipcode': '0', 'country_id': 1, 'locality_verbose': 'Koramangala 5th Block, Bangalore'}, 'switch_to_order_menu': 0, 'cuisines': 'Cafe, American, Burger, Steak', 'timings': '12noon – 3:30pm, 7pm – 10:30pm (Mon),12noon – 10:30pm (Tue-Sun)', 'average_cost_for_two': 900, 'price_range': 2, 'currency': 'Rs.', 'highlights': ['Dinner', 'Takeaway Available', 'Debit Card', 'Lunch', 'Cash', 'Credit Card', 'Indoor Seating', 'Air Conditioned', 'Digital Payments Accepted'], 'offers': [], 'opentable_support': 0, 'is_zomato_book_res': 0, 'mezzo_provider': 'OTHER', 'is_book_form_web_view': 0, 'book_form_web_view_url': '', 'book_again_url': '', 'thumb': 'https://b.zmtcdn.com/data/pictures/chains/8/51038/c312bf371d4e0aea2021a1fd824054ed.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A', 'user_rating': {'aggregate_rating': '4.8', 'rating_text': 'Excellent', 'rating_color': '3F7E00', 'rating_obj': {'title': {'text': '4.8'}, 'bg_color': {'type': 'lime', 'tint': '800'}}, 'votes': 16587}, 'all_reviews_count': 7357, 'photos_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop', 'photo_count': 12504, 'menu_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop', 'featured_image': 'https://b.zmtcdn.com/data/pictures/chains/8/51038/c312bf371d4e0aea2021a1fd824054ed.jpg', 'has_online_delivery': 0, 'is_delivering_now': 0, 'store_type': '', 'include_bogo_offers': True, 'deeplink': 'zomato://restaurant/51040', 'is_table_reservation_supported': 0, 'has_table_booking': 0, 'events_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'phone_numbers': '080 41466565, 080 41536565', 'all_reviews': {'reviews': [{'review': []}, {'review': []}, {'review': []}, {'review': []}, {'review': []}]}, 'establishment': ['Café'], 'establishment_types': []}}, {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1}, 'res_id': 18430785, 'is_grocery_store': False}, 'apikey': 'f9c893da39750138e222b042c8070293', 'id': '18430785', 'name': 'Communiti', 'url': 'https://www.zomato.com/bangalore/communiti-residency-road?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'location': {'address': '67 & 68, Brigade Solitaire, Opposite Advaith Hyundai, Residency Road, Bangalore', 'locality': 'Residency Road', 'city': 'Bangalore', 'city_id': 4, 'latitude': '12.9722191879', 'longitude': '77.6083690301', 'zipcode': '560025', 'country_id': 1, 'locality_verbose': 'Residency Road, Bangalore'}, 'switch_to_order_menu': 0, 'cuisines': 'Continental, BBQ', 'timings': '11:30am – 1am (Mon-Sun)', 'average_cost_for_two': 1500, 'price_range': 3, 'currency': 'Rs.', 'highlights': ['Dinner', 'Takeaway Available', 'Breakfast', 'Lunch', 'Cash', 'Credit Card', 'Debit Card', 'Valet Parking Available', 'Fullbar', 'Indoor Seating', 'Air Conditioned', 'Pet Friendly', 'Craft Beer', 'Outdoor Seating', 'Table booking recommended', 'Smoking Area'], 'offers': [], 'opentable_support': 0, 'is_zomato_book_res': 0, 'mezzo_provider': 'OTHER', 'is_book_form_web_view': 0, 'book_form_web_view_url': '', 'book_again_url': '', 'thumb': 'https://b.zmtcdn.com/data/pictures/5/18430785/21a5bfcd5075 ...
# {'results_found': 7241, 'results_start': 0, 'results_shown': 20, 'restaurants': [{'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1}, 'res_id': 51040, 'is_grocery_store': False}, 'apikey': 'f9c893da39750138e222b042c8070293', 'id': '51040', 'name': 'Truffles', 'url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'location': {'address': '28, 4th B Cross, Koramangala 5th Block, Bangalore', 'locality': 'Koramangala 5th Block', 'city': 'Bangalore', 'city_id': 4, 'latitude': '12.9334920681', 'longitude': '77.6143708080', 'zipcode': '0', 'country_id': 1, 'locality_verbose': 'Koramangala 5th Block, Bangalore'}, 'switch_to_order_menu': 0, 'cuisines': 'Cafe, American, Burger, Steak', 'timings': '12noon – 3:30pm, 7pm – 10:30pm (Mon),12noon – 10:30pm (Tue-Sun)', 'average_cost_for_two': 900, 'price_range': 2, 'currency': 'Rs.', 'highlights': ['Dinner', 'Takeaway Available', 'Debit Card', 'Lunch', 'Cash', 'Credit Card', 'Indoor Seating', 'Air Conditioned', 'Digital Payments Accepted'], 'offers': [], 'opentable_support': 0, 'is_zomato_book_res': 0, 'mezzo_provider': 'OTHER', 'is_book_form_web_view': 0, 'book_form_web_view_url': '', 'book_again_url': '', 'thumb': 'https://b.zmtcdn.com/data/pictures/chains/8/51038/c312bf371d4e0aea2021a1fd824054ed.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A', 'user_rating': {'aggregate_rating': '4.8', 'rating_text': 'Excellent', 'rating_color': '3F7E00', 'rating_obj': {'title': {'text': '4.8'}, 'bg_color': {'type': 'lime', 'tint': '800'}}, 'votes': 16587}, 'all_reviews_count': 7357, 'photos_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop', 'photo_count': 12504, 'menu_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop', 'featured_image': 'https://b.zmtcdn.com/data/pictures/chains/8/51038/c312bf371d4e0aea2021a1fd824054ed.jpg', 'has_online_delivery': 0, 'is_delivering_now': 0, 'store_type': '', 'include_bogo_offers': True, 'deeplink': 'zomato://restaurant/51040', 'is_table_reservation_supported': 0, 'has_table_booking': 0, 'events_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'phone_numbers': '080 41466565, 080 41536565', 'all_reviews': {'reviews': [{'review': []}, {'review': []}, {'review': []}, {'review': []}, {'review': []}]}, 'establishment': ['Café'], 'establishment_types': []}}, {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1}, 'res_id': 18430785, 'is_grocery_store': False}, 'apikey': 'f9c893da39750138e222b042c8070293', 'id': '18430785', 'name': 'Communiti', 'url': 'https://www.zomato.com/bangalore/communiti-residency-road?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'location': {'address': '67 & 68, Brigade Solitaire, Opposite Advaith Hyundai, Residency Road, Bangalore', 'locality': 'Residency Road', 'city': 'Bangalore', 'city_id': 4, 'latitude': '12.9722191879', 'longitude': '77.6083690301', 'zipcode': '560025', 'country_id': 1, 'locality_verbose': 'Residency Road, Bangalore'}, 'switch_to_order_menu': 0, 'cuisines': 'Continental, BBQ', 'timings': '11:30am – 1am (Mon-Sun)', 'average_cost_for_two': 1500, 'price_range': 3, 'currency': 'Rs.', 'highlights': ['Dinner', 'Takeaway Available', 'Breakfast', 'Lunch', 'Cash', 'Credit Card', 'Debit Card', 'Valet Parking Available', 'Fullbar', 'Indoor Seating', 'Air Conditioned', 'Pet Friendly', 'Craft Beer', 'Outdoor Seating', 'Table booking recommended', 'Smoking Area'], 'offers': [], 'opentable_support': 0, 'is_zomato_book_res': 0, 'mezzo_provider': 'OTHER', 'is_book_form_web_view': 0, 'book_form_web_view_url': '', 'book_again_url': '', 'thumb': 'https://b.zmtcdn.com/data/pictures/5/18430785/21a5bfcd5075 ...
# ...
# {'results_found': 7241, 'results_start': 0, 'results_shown': 20, 'restaurants': [{'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1}, 'res_id': 51040, 'is_grocery_store': False}, 'apikey': 'f9c893da39750138e222b042c8070293', 'id': '51040', 'name': 'Truffles', 'url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'location': {'address': '28, 4th B Cross, Koramangala 5th Block, Bangalore', 'locality': 'Koramangala 5th Block', 'city': 'Bangalore', 'city_id': 4, 'latitude': '12.9334920681', 'longitude': '77.6143708080', 'zipcode': '0', 'country_id': 1, 'locality_verbose': 'Koramangala 5th Block, Bangalore'}, 'switch_to_order_menu': 0, 'cuisines': 'Cafe, American, Burger, Steak', 'timings': '12noon – 3:30pm, 7pm – 10:30pm (Mon),12noon – 10:30pm (Tue-Sun)', 'average_cost_for_two': 900, 'price_range': 2, 'currency': 'Rs.', 'highlights': ['Dinner', 'Takeaway Available', 'Debit Card', 'Lunch', 'Cash', 'Credit Card', 'Indoor Seating', 'Air Conditioned', 'Digital Payments Accepted'], 'offers': [], 'opentable_support': 0, 'is_zomato_book_res': 0, 'mezzo_provider': 'OTHER', 'is_book_form_web_view': 0, 'book_form_web_view_url': '', 'book_again_url': '', 'thumb': 'https://b.zmtcdn.com/data/pictures/chains/8/51038/c312bf371d4e0aea2021a1fd824054ed.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A', 'user_rating': {'aggregate_rating': '4.8', 'rating_text': 'Excellent', 'rating_color': '3F7E00', 'rating_obj': {'title': {'text': '4.8'}, 'bg_color': {'type': 'lime', 'tint': '800'}}, 'votes': 16587}, 'all_reviews_count': 7357, 'photos_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop', 'photo_count': 12504, 'menu_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop', 'featured_image': 'https://b.zmtcdn.com/data/pictures/chains/8/51038/c312bf371d4e0aea2021a1fd824054ed.jpg', 'has_online_delivery': 0, 'is_delivering_now': 0, 'store_type': '', 'include_bogo_offers': True, 'deeplink': 'zomato://restaurant/51040', 'is_table_reservation_supported': 0, 'has_table_booking': 0, 'events_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'phone_numbers': '080 41466565, 080 41536565', 'all_reviews': {'reviews': [{'review': []}, {'review': []}, {'review': []}, {'review': []}, {'review': []}]}, 'establishment': ['Café'], 'establishment_types': []}}, {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1}, 'res_id': 18430785, 'is_grocery_store': False}, 'apikey': 'f9c893da39750138e222b042c8070293', 'id': '18430785', 'name': 'Communiti', 'url': 'https://www.zomato.com/bangalore/communiti-residency-road?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'location': {'address': '67 & 68, Brigade Solitaire, Opposite Advaith Hyundai, Residency Road, Bangalore', 'locality': 'Residency Road', 'city': 'Bangalore', 'city_id': 4, 'latitude': '12.9722191879', 'longitude': '77.6083690301', 'zipcode': '560025', 'country_id': 1, 'locality_verbose': 'Residency Road, Bangalore'}, 'switch_to_order_menu': 0, 'cuisines': 'Continental, BBQ', 'timings': '11:30am – 1am (Mon-Sun)', 'average_cost_for_two': 1500, 'price_range': 3, 'currency': 'Rs.', 'highlights': ['Dinner', 'Takeaway Available', 'Breakfast', 'Lunch', 'Cash', 'Credit Card', 'Debit Card', 'Valet Parking Available', 'Fullbar', 'Indoor Seating', 'Air Conditioned', 'Pet Friendly', 'Craft Beer', 'Outdoor Seating', 'Table booking recommended', 'Smoking Area'], 'offers': [], 'opentable_support': 0, 'is_zomato_book_res': 0, 'mezzo_provider': 'OTHER', 'is_book_form_web_view': 0, 'book_form_web_view_url': '', 'book_again_url': '', 'thumb': 'https://b.zmtcdn.com/data/pictures/5/18430785/21a5bfcd5075 ...
# {'results_found': 7242, 'results_start': 0, 'results_shown': 20, 'restaurants': [{'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1}, 'res_id': 51040, 'is_grocery_store': False}, 'apikey': 'f9c893da39750138e222b042c8070293', 'id': '51040', 'name': 'Truffles', 'url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'location': {'address': '28, 4th B Cross, Koramangala 5th Block, Bangalore', 'locality': 'Koramangala 5th Block', 'city': 'Bangalore', 'city_id': 4, 'latitude': '12.9334920681', 'longitude': '77.6143708080', 'zipcode': '0', 'country_id': 1, 'locality_verbose': 'Koramangala 5th Block, Bangalore'}, 'switch_to_order_menu': 0, 'cuisines': 'Cafe, American, Burger, Steak', 'timings': '12noon – 3:30pm, 7pm – 10:30pm (Mon),12noon – 10:30pm (Tue-Sun)', 'average_cost_for_two': 900, 'price_range': 2, 'currency': 'Rs.', 'highlights': ['Dinner', 'Takeaway Available', 'Debit Card', 'Lunch', 'Cash', 'Credit Card', 'Indoor Seating', 'Air Conditioned', 'Digital Payments Accepted'], 'offers': [], 'opentable_support': 0, 'is_zomato_book_res': 0, 'mezzo_provider': 'OTHER', 'is_book_form_web_view': 0, 'book_form_web_view_url': '', 'book_again_url': '', 'thumb': 'https://b.zmtcdn.com/data/pictures/chains/8/51038/c312bf371d4e0aea2021a1fd824054ed.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A', 'user_rating': {'aggregate_rating': '4.8', 'rating_text': 'Excellent', 'rating_color': '3F7E00', 'rating_obj': {'title': {'text': '4.8'}, 'bg_color': {'type': 'lime', 'tint': '800'}}, 'votes': 16587}, 'all_reviews_count': 7357, 'photos_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop', 'photo_count': 12504, 'menu_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop', 'featured_image': 'https://b.zmtcdn.com/data/pictures/chains/8/51038/c312bf371d4e0aea2021a1fd824054ed.jpg', 'has_online_delivery': 0, 'is_delivering_now': 0, 'store_type': '', 'include_bogo_offers': True, 'deeplink': 'zomato://restaurant/51040', 'is_table_reservation_supported': 0, 'has_table_booking': 0, 'events_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'phone_numbers': '080 41466565, 080 41536565', 'all_reviews': {'reviews': [{'review': []}, {'review': []}, {'review': []}, {'review': []}, {'review': []}]}, 'establishment': ['Café'], 'establishment_types': []}}, {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1}, 'res_id': 18430785, 'is_grocery_store': False}, 'apikey': 'f9c893da39750138e222b042c8070293', 'id': '18430785', 'name': 'Communiti', 'url': 'https://www.zomato.com/bangalore/communiti-residency-road?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'location': {'address': '67 & 68, Brigade Solitaire, Opposite Advaith Hyundai, Residency Road, Bangalore', 'locality': 'Residency Road', 'city': 'Bangalore', 'city_id': 4, 'latitude': '12.9722191879', 'longitude': '77.6083690301', 'zipcode': '560025', 'country_id': 1, 'locality_verbose': 'Residency Road, Bangalore'}, 'switch_to_order_menu': 0, 'cuisines': 'Continental, BBQ', 'timings': '11:30am – 1am (Mon-Sun)', 'average_cost_for_two': 1500, 'price_range': 3, 'currency': 'Rs.', 'highlights': ['Dinner', 'Takeaway Available', 'Breakfast', 'Lunch', 'Cash', 'Credit Card', 'Debit Card', 'Valet Parking Available', 'Fullbar', 'Indoor Seating', 'Air Conditioned', 'Pet Friendly', 'Craft Beer', 'Outdoor Seating', 'Table booking recommended', 'Smoking Area'], 'offers': [], 'opentable_support': 0, 'is_zomato_book_res': 0, 'mezzo_provider': 'OTHER', 'is_book_form_web_view': 0, 'book_form_web_view_url': '', 'book_again_url': '', 'thumb': 'https://b.zmtcdn.com/data/pictures/5/18430785/21a5bfcd5075 ...
# {'results_found': 7241, 'results_start': 0, 'results_shown': 20, 'restaurants': [{'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1}, 'res_id': 51040, 'is_grocery_store': False}, 'apikey': 'f9c893da39750138e222b042c8070293', 'id': '51040', 'name': 'Truffles', 'url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'location': {'address': '28, 4th B Cross, Koramangala 5th Block, Bangalore', 'locality': 'Koramangala 5th Block', 'city': 'Bangalore', 'city_id': 4, 'latitude': '12.9334920681', 'longitude': '77.6143708080', 'zipcode': '0', 'country_id': 1, 'locality_verbose': 'Koramangala 5th Block, Bangalore'}, 'switch_to_order_menu': 0, 'cuisines': 'Cafe, American, Burger, Steak', 'timings': '12noon – 3:30pm, 7pm – 10:30pm (Mon),12noon – 10:30pm (Tue-Sun)', 'average_cost_for_two': 900, 'price_range': 2, 'currency': 'Rs.', 'highlights': ['Dinner', 'Takeaway Available', 'Debit Card', 'Lunch', 'Cash', 'Credit Card', 'Indoor Seating', 'Air Conditioned', 'Digital Payments Accepted'], 'offers': [], 'opentable_support': 0, 'is_zomato_book_res': 0, 'mezzo_provider': 'OTHER', 'is_book_form_web_view': 0, 'book_form_web_view_url': '', 'book_again_url': '', 'thumb': 'https://b.zmtcdn.com/data/pictures/chains/8/51038/c312bf371d4e0aea2021a1fd824054ed.jpg?fit=around%7C200%3A200&crop=200%3A200%3B%2A%2C%2A', 'user_rating': {'aggregate_rating': '4.8', 'rating_text': 'Excellent', 'rating_color': '3F7E00', 'rating_obj': {'title': {'text': '4.8'}, 'bg_color': {'type': 'lime', 'tint': '800'}}, 'votes': 16587}, 'all_reviews_count': 7357, 'photos_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/photos?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1#tabtop', 'photo_count': 12504, 'menu_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/menu?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1&openSwipeBox=menu&showMinimal=1#tabtop', 'featured_image': 'https://b.zmtcdn.com/data/pictures/chains/8/51038/c312bf371d4e0aea2021a1fd824054ed.jpg', 'has_online_delivery': 0, 'is_delivering_now': 0, 'store_type': '', 'include_bogo_offers': True, 'deeplink': 'zomato://restaurant/51040', 'is_table_reservation_supported': 0, 'has_table_booking': 0, 'events_url': 'https://www.zomato.com/bangalore/truffles-koramangala-5th-block/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'phone_numbers': '080 41466565, 080 41536565', 'all_reviews': {'reviews': [{'review': []}, {'review': []}, {'review': []}, {'review': []}, {'review': []}]}, 'establishment': ['Café'], 'establishment_types': []}}, {'restaurant': {'R': {'has_menu_status': {'delivery': -1, 'takeaway': -1}, 'res_id': 18430785, 'is_grocery_store': False}, 'apikey': 'f9c893da39750138e222b042c8070293', 'id': '18430785', 'name': 'Communiti', 'url': 'https://www.zomato.com/bangalore/communiti-residency-road?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1', 'location': {'address': '67 & 68, Brigade Solitaire, Opposite Advaith Hyundai, Residency Road, Bangalore', 'locality': 'Residency Road', 'city': 'Bangalore', 'city_id': 4, 'latitude': '12.9722191879', 'longitude': '77.6083690301', 'zipcode': '560025', 'country_id': 1, 'locality_verbose': 'Residency Road, Bangalore'}, 'switch_to_order_menu': 0, 'cuisines': 'Continental, BBQ', 'timings': '11:30am – 1am (Mon-Sun)', 'average_cost_for_two': 1500, 'price_range': 3, 'currency': 'Rs.', 'highlights': ['Dinner', 'Takeaway Available', 'Breakfast', 'Lunch', 'Cash', 'Credit Card', 'Debit Card', 'Valet Parking Available', 'Fullbar', 'Indoor Seating', 'Air Conditioned', 'Pet Friendly', 'Craft Beer', 'Outdoor Seating', 'Table booking recommended', 'Smoking Area'], 'offers': [], 'opentable_support': 0, 'is_zomato_book_res': 0, 'mezzo_provider': 'OTHER', 'is_book_form_web_view': 0, 'book_form_web_view_url': '', 'book_again_url': '', 'thumb': 'https://b.zmtcdn.com/data/pictures/5/18430785/21a5bfcd5075 ...
# --- 12.478274822235107 seconds ---
# 480

# %%
start_time = time.time()
print("i am inside action_search_restaurants")
# My API Key of Zomato
config = {"user_key":"f9c893da39750138e222b042c8070293"}
zomato = zomatopy.initialize_app(config)

# Price range determination
price = 1
print(price)
# Get the user selected cuisine
# Slot 'cuisine' would have been updated in the ActionCheckCuisine() with correct cuisine name
cuisine = 'chinese'
print(cuisine)
# Get the user selected location
# Slot 'location' would have been updated in the ActionCheckCity() with correct city name		
loc = 'Bangalore'
print(loc)
# Cuisines code (used by zomato)
# Source: https://developers.zomato.com/documentation?lang=tr#/
cuisines_dict = {'american':1,'chinese':25,'mexican':73,'italian':55,'north indian':50,'south indian':85}

# Prepare the response
response = []
initialResponse = ""
# As long as there is a valid location specified
if (loc != 'unlisted'):
    # get_location gets the lat-long coordinates of 'loc'
    location_detail = zomato.get_location(loc, 1)
    # Store retrieved data as a dict
    d = json.loads(location_detail)
    city_id = d["location_suggestions"][0]["city_id"]
    # Fetch results
    #getMetaData = zomato.restaurant_search_by_city(city_id, str(cuisines_dict[cuisine]), 0)
    #metadata = json.loads(getMetaData)
    #maxData = metadata['results_found']
    # If cuisine is specified, then use that to search restaurants
    if (cuisine != 'unlisted'):
        count = 0
        for offset in range(0, 500, 20):
            print(count)
            #results = zomato.restaurant_search_by_city(city_id, str(cuisines_dict[cuisine]), offset)
            loop = asyncio.get_event_loop()
            if loop.is_running() == False:
                results = asyncio.run(zomato.restaurant_search_by_city_async(city_id, str(cuisines_dict[cuisine]), offset))
            else:
                results = await zomato.restaurant_search_by_city_async(city_id, str(cuisines_dict[cuisine]), offset)
            d1 = json.loads(results)
            if (count>=10) or (offset>d1['results_found']):
                break
            # If no results match with the user mentioned criteria
            if d1['results_found'] == 0:
                initialResponse = "No restaurants found matching your criteria"
                print(initialResponse)
            else:           
                initialResponse =  "Here are the top rated restaurants as per your criteria:"+"\n"
                for restaurant in d1['restaurants']: 
                    if count>=10:
                        break
                    # Getting Top 10 restaurants for the lower price range
                    if ((float(price) == 1) and (restaurant['restaurant']['average_cost_for_two'] < 300) and (cuisine.title() in restaurant['restaurant']['cuisines'])):
                        response.append(restaurant['restaurant']['name']+ " in "+ restaurant['restaurant']['location']['address']+ " has a rating of "+ restaurant['restaurant']['user_rating']['aggregate_rating']+".")
                        response.append("The average price of Rs."+ str(restaurant['restaurant']['average_cost_for_two'])+ "for two persons" + "\n")
                        count = count + 1

                    # Getting Top 10 restaurants for the mid price range
                    elif ((float(price) == 2) and (restaurant['restaurant']['average_cost_for_two'] >= 300) and (restaurant['restaurant']['average_cost_for_two'] <= 700) and (cuisine.title() in restaurant['restaurant']['cuisines'])):
                        response.append(restaurant['restaurant']['name']+ " in "+ restaurant['restaurant']['location']['address']+ " has a rating of "+ restaurant['restaurant']['user_rating']['aggregate_rating']+"\n")
                        response.append("The average price of Rs."+ str(restaurant['restaurant']['average_cost_for_two'])+ "for two persons" + "\n")
                        count = count + 1 

                    # Getting Top 10 restaurants for the higher price range                       
                    elif ((float(price) == 3) and (restaurant['restaurant']['average_cost_for_two'] > 700) and (cuisine.title() in restaurant['restaurant']['cuisines'])):
                        response.append(restaurant['restaurant']['name']+ " in "+ restaurant['restaurant']['location']['address']+ " has a rating of "+ restaurant['restaurant']['user_rating']['aggregate_rating']+"\n")
                        response.append("The average price of Rs."+ str(restaurant['restaurant']['average_cost_for_two'])+ "for two persons" + "\n")
                        count = count + 1
                    
    # Cuisine is not specified, hence search for all cuisine types
    else:
        count = 0
        for offset in range(0, 1000, 20):
            #results = zomato.restaurant_search_by_city(city_id, "", offset)
            loop = asyncio.get_event_loop()
            if loop.is_running() == False:
                results = asyncio.run(zomato.restaurant_search_by_city_async(city_id, str(cuisines_dict[cuisine]), offset))
            else:
                results = await zomato.restaurant_search_by_city_async(city_id, str(cuisines_dict[cuisine]), offset)

            d1 = json.loads(results)
            if (count>=10) or (offset>d1['results_found']):
                break
            # If no results match with the user mentioned criteria
            if d1['results_found'] == 0:
                initialResponse = "No restaurants found matching your criteria"
                print(initialResponse)
            else:           
                initialResponse = "Here are the top rated restaurants as per your criteria:"+"\n"
                for restaurant in d1['restaurants']: 
                    if count>=10:
                        break
                    # Getting Top 10 restaurants for the lower price range
                    if ((float(price) == 1) and (restaurant['restaurant']['average_cost_for_two'] < 300)):
                        response.append(restaurant['restaurant']['name']+ " in "+ restaurant['restaurant']['location']['address']+ " has a rating of "+ restaurant['restaurant']['user_rating']['aggregate_rating']+".")
                        response.append("The average price of Rs."+ str(restaurant['restaurant']['average_cost_for_two'])+ "for two persons" + "\n")
                        count = count + 1

                    # Getting Top 10 restaurants for the mid price range
                    elif ((float(price) == 2) and (restaurant['restaurant']['average_cost_for_two'] >= 300) and (restaurant['restaurant']['average_cost_for_two'] <= 700)):
                        response.append(restaurant['restaurant']['name']+ " in "+ restaurant['restaurant']['location']['address']+ " has a rating of "+ restaurant['restaurant']['user_rating']['aggregate_rating']+"\n")
                        response.append("The average price of Rs."+ str(restaurant['restaurant']['average_cost_for_two'])+ "for two persons" + "\n")
                        count = count + 1 

                    # Getting Top 10 restaurants for the higher price range                       
                    elif ((float(price) == 3) and (restaurant['restaurant']['average_cost_for_two'] > 700)):
                        response.append(restaurant['restaurant']['name']+ " in "+ restaurant['restaurant']['location']['address']+ " has a rating of "+ restaurant['restaurant']['user_rating']['aggregate_rating']+"\n")
                        response.append("The average price of Rs."+ str(restaurant['restaurant']['average_cost_for_two'])+ "for two persons" + "\n")
                        count = count + 1

        
    # If no results obtained
    if(count == 0):
        initialResponse = "Sorry, No results found for your criteria. Would you like to search for some other restaurants?"
        print(initialResponse)
    # Display the results
    else:
        print(initialResponse)
        for res in response[::2][:5]:
            print(res)

# If no valid location is given
else:
    response = "Sorry, we don’t operate in this city. Please specify some other location"
    print(response)
print("--- %s seconds ---" % (time.time() - start_time))
print(offset)
# Out:
# i am inside action_search_restaurants
# 1
# chinese
# Bangalore
# 0
# 0
# 0
# 2
# 2
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# Here are the top rated restaurants as per your criteria:
#
# Sri Vishnu Upahar in Opposite Manapuram Gold Loan, Koramangala 4th Block, Bangalore has a rating of 4.5.
# Smogrill in Opposite Kayla Spa N Saloon, Jaladarshini Layout, New BEL Road, Bangalore has a rating of 4.5.
# Fullyfilled in House 68, 10th Main, 4th Cross, Indiranagar, Bengaluru has a rating of 4.4.
# --- 8.136742353439331 seconds ---
# 480

# %%
start_time = time.time()
print("i am inside action_search_restaurants")
# My API Key of Zomato
config = {"user_key":"f9c893da39750138e222b042c8070293"}
zomato = zomatopy.initialize_app(config)

# Price range determination
price = 1
print(price)
# Get the user selected cuisine
# Slot 'cuisine' would have been updated in the ActionCheckCuisine() with correct cuisine name
cuisine = 'chinese'
print(cuisine)
# Get the user selected location
# Slot 'location' would have been updated in the ActionCheckCity() with correct city name		
loc = 'Bangalore'
print(loc)
# Cuisines code (used by zomato)
# Source: https://developers.zomato.com/documentation?lang=tr#/
cuisines_dict = {'american':1,'chinese':25,'mexican':73,'italian':55,'north indian':50,'south indian':85}

# Prepare the response
response = []
initialResponse = ""
# As long as there is a valid location specified
if (loc != 'unlisted'):
    # get_location gets the lat-long coordinates of 'loc'
    location_detail = zomato.get_location(loc, 1)
    # Store retrieved data as a dict
    d = json.loads(location_detail)
    city_id = d["location_suggestions"][0]["city_id"]
    # Fetch results
    #getMetaData = zomato.restaurant_search_by_city(city_id, str(cuisines_dict[cuisine]), 0)
    #metadata = json.loads(getMetaData)
    #maxData = metadata['results_found']
    # If cuisine is specified, then use that to search restaurants
    if (cuisine != 'unlisted'):
        count = 0
        for offset in range(0, 500, 20):
            print(count)
            results = zomato.restaurant_search_by_city(city_id, str(cuisines_dict[cuisine]), offset)
            d1 = json.loads(results)
            if (count>=10) or (offset>d1['results_found']):
                break
            # If no results match with the user mentioned criteria
            if d1['results_found'] == 0:
                initialResponse = "No restaurants found matching your criteria"
                print(initialResponse)
            else:           
                initialResponse =  "Here are the top rated restaurants as per your criteria:"+"\n"
                for restaurant in d1['restaurants']: 
                    if count>=10:
                        break
                    # Getting Top 10 restaurants for the lower price range
                    if ((float(price) == 1) and (restaurant['restaurant']['average_cost_for_two'] < 300) and (cuisine.title() in restaurant['restaurant']['cuisines'])):
                        response.append(restaurant['restaurant']['name']+ " in "+ restaurant['restaurant']['location']['address']+ " has a rating of "+ restaurant['restaurant']['user_rating']['aggregate_rating']+".")
                        response.append("The average price of Rs."+ str(restaurant['restaurant']['average_cost_for_two'])+ "for two persons" + "\n")
                        count = count + 1

                    # Getting Top 10 restaurants for the mid price range
                    elif ((float(price) == 2) and (restaurant['restaurant']['average_cost_for_two'] >= 300) and (restaurant['restaurant']['average_cost_for_two'] <= 700) and (cuisine.title() in restaurant['restaurant']['cuisines'])):
                        response.append(restaurant['restaurant']['name']+ " in "+ restaurant['restaurant']['location']['address']+ " has a rating of "+ restaurant['restaurant']['user_rating']['aggregate_rating']+"\n")
                        response.append("The average price of Rs."+ str(restaurant['restaurant']['average_cost_for_two'])+ "for two persons" + "\n")
                        count = count + 1 

                    # Getting Top 10 restaurants for the higher price range                       
                    elif ((float(price) == 3) and (restaurant['restaurant']['average_cost_for_two'] > 700) and (cuisine.title() in restaurant['restaurant']['cuisines'])):
                        response.append(restaurant['restaurant']['name']+ " in "+ restaurant['restaurant']['location']['address']+ " has a rating of "+ restaurant['restaurant']['user_rating']['aggregate_rating']+"\n")
                        response.append("The average price of Rs."+ str(restaurant['restaurant']['average_cost_for_two'])+ "for two persons" + "\n")
                        count = count + 1
                    
    # Cuisine is not specified, hence search for all cuisine types
    else:
        count = 0
        for offset in range(0, 1000, 20):
            results = zomato.restaurant_search_by_city(city_id, "", offset)
            d1 = json.loads(results)
            if (count>=10) or (offset>d1['results_found']):
                break
            # If no results match with the user mentioned criteria
            if d1['results_found'] == 0:
                initialResponse = "No restaurants found matching your criteria"
                print(initialResponse)
            else:           
                initialResponse = "Here are the top rated restaurants as per your criteria:"+"\n"
                for restaurant in d1['restaurants']: 
                    if count>=10:
                        break
                    # Getting Top 10 restaurants for the lower price range
                    if ((float(price) == 1) and (restaurant['restaurant']['average_cost_for_two'] < 300)):
                        response.append(restaurant['restaurant']['name']+ " in "+ restaurant['restaurant']['location']['address']+ " has a rating of "+ restaurant['restaurant']['user_rating']['aggregate_rating']+".")
                        response.append("The average price of Rs."+ str(restaurant['restaurant']['average_cost_for_two'])+ "for two persons" + "\n")
                        count = count + 1

                    # Getting Top 10 restaurants for the mid price range
                    elif ((float(price) == 2) and (restaurant['restaurant']['average_cost_for_two'] >= 300) and (restaurant['restaurant']['average_cost_for_two'] <= 700)):
                        response.append(restaurant['restaurant']['name']+ " in "+ restaurant['restaurant']['location']['address']+ " has a rating of "+ restaurant['restaurant']['user_rating']['aggregate_rating']+"\n")
                        response.append("The average price of Rs."+ str(restaurant['restaurant']['average_cost_for_two'])+ "for two persons" + "\n")
                        count = count + 1 

                    # Getting Top 10 restaurants for the higher price range                       
                    elif ((float(price) == 3) and (restaurant['restaurant']['average_cost_for_two'] > 700)):
                        response.append(restaurant['restaurant']['name']+ " in "+ restaurant['restaurant']['location']['address']+ " has a rating of "+ restaurant['restaurant']['user_rating']['aggregate_rating']+"\n")
                        response.append("The average price of Rs."+ str(restaurant['restaurant']['average_cost_for_two'])+ "for two persons" + "\n")
                        count = count + 1

        
    # If no results obtained
    if(count == 0):
        initialResponse = "Sorry, No results found for your criteria. Would you like to search for some other restaurants?"
        print(initialResponse)
    # Display the results
    else:
        print(initialResponse)
        for res in response[::2][:5]:
            print(res)

# If no valid location is given
else:
    response = "Sorry, we don’t operate in this city. Please specify some other location"
    print(response)
print("--- %s seconds ---" % (time.time() - start_time))
print(offset)
# Out:
# i am inside action_search_restaurants
# 1
# chinese
# Bangalore
# 0
# 0
# 0
# 2
# 2
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# 3
# Here are the top rated restaurants as per your criteria:
#
# Sri Vishnu Upahar in Opposite Manapuram Gold Loan, Koramangala 4th Block, Bangalore has a rating of 4.5.
# Smogrill in Opposite Kayla Spa N Saloon, Jaladarshini Layout, New BEL Road, Bangalore has a rating of 4.5.
# Fullyfilled in House 68, 10th Main, 4th Cross, Indiranagar, Bengaluru has a rating of 4.4.
# --- 9.12856149673462 seconds ---
# 480

# %%
        start_time = time.time()
        print("i am inside action_search_restaurants")
        # My API Key of Zomato
        config = {"user_key":"f9c893da39750138e222b042c8070293"}
        zomato = zomatopy.initialize_app(config)

        # Price range determination
        price = 2
        print(price)
        # Get the user selected cuisine
        # Slot 'cuisine' would have been updated in the ActionCheckCuisine() with correct cuisine name
        cuisine = 'chinese'
        print(cuisine)
        # Get the user selected location
        # Slot 'location' would have been updated in the ActionCheckCity() with correct city name		
        city_id = 4
        print(city_id)
        # Cuisines code (used by zomato)
        # Source: https://developers.zomato.com/documentation?lang=tr#/
        cuisines_dict = {'american':1,'chinese':25,'mexican':73,'italian':55,'north indian':50,'south indian':85}

        # Prepare the response
        response = []
        initialResponse = ""
        # As long as there is a valid location specified
        if (city_id != 'unlisted'):
            # get_location gets the lat-long coordinates of 'loc'
            #location_detail = zomato.get_location(loc, 1)
            # Store retrieved data as a dict
            #d = json.loads(location_detail)
            #city_id = d["location_suggestions"][0]["city_id"]
            # Fetch results
            #getMetaData = zomato.restaurant_search_by_city(city_id, str(cuisines_dict[cuisine]), 0)
            #metadata = json.loads(getMetaData)
            #maxData = metadata['results_found']
            # If cuisine is specified, then use that to search restaurants
            if (cuisine != 'unlisted'):
                count = 0
                for offset in range(0, 1000, 20):
                    results = zomato.restaurant_search_by_city(city_id, str(cuisines_dict[cuisine]), offset)
                    d1 = json.loads(results)
                    if (count>=10) or (offset>d1['results_found']):
                        break
                    # If no results match with the user mentioned criteria
                    if d1['results_found'] == 0:
                        initialResponse = "No restaurants found matching your criteria"
                        dispatcher.utter_message(initialResponse)
                    else:           
                        initialResponse =  "Here are the top rated restaurants as per your criteria:"+"\n"
                        for restaurant in d1['restaurants']: 
                            if count>=10:
                                break
                            # Getting Top 10 restaurants for the lower price range
                            if ((float(price) == 1) and (restaurant['restaurant']['average_cost_for_two'] < 300) and (cuisine.title() in restaurant['restaurant']['cuisines'])):
                                response.append(restaurant['restaurant']['name']+ " in "+ restaurant['restaurant']['location']['address']+ " has a rating of "+ restaurant['restaurant']['user_rating']['aggregate_rating']+".")
                                response.append("The average price of Rs."+ str(restaurant['restaurant']['average_cost_for_two'])+ "for two persons" + "\n")
                                count = count + 1

                            # Getting Top 10 restaurants for the mid price range
                            elif ((float(price) == 2) and (restaurant['restaurant']['average_cost_for_two'] >= 300) and (restaurant['restaurant']['average_cost_for_two'] <= 700) and (cuisine.title() in restaurant['restaurant']['cuisines'])):
                                response.append(restaurant['restaurant']['name']+ " in "+ restaurant['restaurant']['location']['address']+ " has a rating of "+ restaurant['restaurant']['user_rating']['aggregate_rating']+"\n")
                                response.append("The average price of Rs."+ str(restaurant['restaurant']['average_cost_for_two'])+ "for two persons" + "\n")
                                count = count + 1 

                            # Getting Top 10 restaurants for the higher price range                       
                            elif ((float(price) == 3) and (restaurant['restaurant']['average_cost_for_two'] > 700) and (cuisine.title() in restaurant['restaurant']['cuisines'])):
                                response.append(restaurant['restaurant']['name']+ " in "+ restaurant['restaurant']['location']['address']+ " has a rating of "+ restaurant['restaurant']['user_rating']['aggregate_rating']+"\n")
                                response.append("The average price of Rs."+ str(restaurant['restaurant']['average_cost_for_two'])+ "for two persons" + "\n")
                                count = count + 1
                            
            # Cuisine is not specified, hence search for all cuisine types
            else:
                count = 0
                print("inside else cuisine")
                for offset in range(0, 1000, 20):
                    results = zomato.restaurant_search_by_city(city_id, "", offset)
                    d1 = json.loads(results)
                    if (count>=10) or (offset>d1['results_found']):
                        break
                    # If no results match with the user mentioned criteria
                    if d1['results_found'] == 0:
                        initialResponse = "No restaurants found matching your criteria"
                        dispatcher.utter_message(initialResponse)
                    else:           
                        initialResponse = "Here are the top rated restaurants as per your criteria:"+"\n"
                        for restaurant in d1['restaurants']: 
                            if count>=10:
                                break
                            # Getting Top 10 restaurants for the lower price range
                            if ((float(price) == 1) and (restaurant['restaurant']['average_cost_for_two'] < 300)):
                                response.append(restaurant['restaurant']['name']+ " in "+ restaurant['restaurant']['location']['address']+ " has a rating of "+ restaurant['restaurant']['user_rating']['aggregate_rating']+".")
                                response.append("The average price of Rs."+ str(restaurant['restaurant']['average_cost_for_two'])+ "for two persons" + "\n")
                                count = count + 1

                            # Getting Top 10 restaurants for the mid price range
                            elif ((float(price) == 2) and (restaurant['restaurant']['average_cost_for_two'] >= 300) and (restaurant['restaurant']['average_cost_for_two'] <= 700)):
                                response.append(restaurant['restaurant']['name']+ " in "+ restaurant['restaurant']['location']['address']+ " has a rating of "+ restaurant['restaurant']['user_rating']['aggregate_rating']+"\n")
                                response.append("The average price of Rs."+ str(restaurant['restaurant']['average_cost_for_two'])+ "for two persons" + "\n")
                                count = count + 1 

                            # Getting Top 10 restaurants for the higher price range                       
                            elif ((float(price) == 3) and (restaurant['restaurant']['average_cost_for_two'] > 700)):
                                response.append(restaurant['restaurant']['name']+ " in "+ restaurant['restaurant']['location']['address']+ " has a rating of "+ restaurant['restaurant']['user_rating']['aggregate_rating']+"\n")
                                response.append("The average price of Rs."+ str(restaurant['restaurant']['average_cost_for_two'])+ "for two persons" + "\n")
                                count = count + 1

                
            # If no results obtained
            if(count == 0):
                initialResponse = "Sorry, No results found for your criteria. Would you like to search for some other restaurants?"
                dispatcher.utter_message(initialResponse)
            # Display the results
            else:
                print(initialResponse)
                for res in response[::2][:5]:
                    print(res)

        # If no valid location is given
        else:
            response = "Sorry, we don’t operate in this city. Please specify some other location"
            print(response)
        print(offset)   
        print("--- %s seconds ---" % (time.time() - start_time))

# %%
    location_detail = zomato.get_location(loc, 1)
    print(location_detail)
    # Store retrieved data as a dict
    d = json.loads(location_detail)
    d["location_suggestions"][0]["city_id"]

# %%
d['results_found']

# %%
 for restaurant in d['restaurants']: 
        print('chinese'.title() in restaurant['restaurant']['cuisines'])

# %%
count=0
for restaurant in sorted(d['restaurants'], key = lambda x: x['restaurant']['user_rating']['aggregate_rating'], reverse = True): 
# Getting Top 10 restaurants for the lower price range
            if ((float(price) == 1) and (restaurant['restaurant']['average_cost_for_two'] < 300) and (count < 10)):
                response = response + restaurant['restaurant']['name']+ " in "+ restaurant['restaurant']['location']['address']+ " has a rating of "+ restaurant['restaurant']['user_rating']['aggregate_rating']+"."
                response = response +" with the average price of Rs."+ str(restaurant['restaurant']['average_cost_for_two'])+ "for two persons" + "\n"
                count = count + 1

# %%
restaurant['restaurant']['average_cost_for_two']

# %%
print("i am inside action_search_restaurants")
# My API Key of Zomato
config = {"user_key":"f9c893da39750138e222b042c8070293"}
zomato = zomatopy.initialize_app(config)

# Price range determination
price = '1'
print(price)
# Get the user selected cuisine
# Slot 'cuisine' would have been updated in the ActionCheckCuisine() with correct cuisine name
cuisine = 'chinese'
print(cuisine)
# Get the user selected location
# Slot 'location' would have been updated in the ActionCheckCity() with correct city name		
loc = 'Bangalore'
print(loc)
# Cuisines code (used by zomato)
# Source: https://developers.zomato.com/documentation?lang=tr#/
cuisines_dict = {'american':1,'chinese':25,'mexican':73,'italian':55,'north indian':50,'south indian':85}

# Prepare the response
response = ""

# As long as there is a valid location specified
if (loc != 'unlisted'):
    # get_location gets the lat-long coordinates of 'loc'
    location_detail = zomato.get_location(loc, 1)
    print(location_detail)
    # Store retrieved data as a dict
    d1 = json.loads(location_detail)
    # Separate lat-long coordinates
    lat = d1["location_suggestions"][0]["latitude"]
    lon = d1["location_suggestions"][0]["longitude"]

    # Fetch results
    # If cuisine is specified, then use that to search restaurants
    if (cuisine != 'unlisted'):
        print(location_detail)
        results = zomato.restaurant_search("", lat, lon, str(cuisines_dict.get(cuisine)), 10000)
    # Cuisine is not specified, hence search for all cuisine types
    else:
        results = zomato.restaurant_search("", lat, lon, 10000)
    d = json.loads(results)
    print(d)
    # Counter to output top 10 results
    count = 0

    # If no results match with the user mentioned criteria
    if d['results_found'] == 0:
        response = "No restaurants found matching your criteria"
        print(response)
    else:           
        response = "Here are the top rated restaurants as per your criteria:"+"\n"

        # Get the restaurants ordered as per their user rating

# %%
for restaurant in sorted(d['restaurants'], key = lambda x: x['restaurant']['user_rating']['aggregate_rating'], reverse = True):
        print(restaurant['restaurant']['average_cost_for_two'])

# %%
lst=[]

for val in range(0,100,20):
    results=zomato.restaurant_search("", lat, lon, str(cuisines_dict.get(cuisine)),val)
    d = json.loads(results)
    if val == 20:
        q1 = d
    elif val == 40:
        q2 = d
    elif val == 60:
        q3 = d
    elif val == 80:
        q4 = d
    for restaurant in d['restaurants']:
        lst.append((restaurant['restaurant']['name'],restaurant['restaurant']['location']['address'],float(restaurant['restaurant']['average_cost_for_two']),float(restaurant['restaurant']['user_rating']['aggregate_rating'])))

lst

# %%
len(lst)

# %%
lst1=sorted(lst,key=lambda x:x[3],reverse=True)
lst1

# %%
def get_soundex(token):
    temp=''
    token=token.upper()
    temp+=token[0]
    dic={'BFPV':1,'CGJKQSXZ':2,'DT':3,'L':4,'MN':5,'R':6,'AEIOUYHW':''}
    
    for char in token[1:]:
        for key in dic.keys():
            if char in key:
                code=str(dic[key])
                break
        if temp[-1]!=code:
            temp+=code
    temp=temp[:4].ljust(4,'0')
    return temp

# %%
cuisines = {get_soundex('chinese'):'chinese', get_soundex('mexican'):'mexican', get_soundex('italian'):'italian',
       get_soundex('american'):'american', get_soundex('south indian'):'south indian', get_soundex('north indian'):'north indian'}

cuisines

# %%
cuisine = 'maksikaan'
# Check if the user selected cuisine is in the list
if get_soundex(cuisine) in cuisines.keys():
    cuisine = cuisines[get_soundex(cuisine)]
    
cuisine

# %%
# Tier 1 and 2 cities listed in wikipedia https://en.wikipedia.org/wiki/Classification_of_Indian_cities
city_list = ['Ahmedabad', 'Bangalore', 'Chennai', 'Delhi', 'Hyderabad', 'Kolkata', 'Mumbai', 'Pune', 'Jaipur', 
                  'Coimbatore', 'Agra', 'Ajmer', 'Aligarh', 'Amravati', 'Amritsar', 'Asansol', 'Aurangabad', 'Bareilly', 
                  'Belgaum', 'Bhavnagar', 'Bhiwandi', 'Bhopal', 'Bhubaneswar', 'Bikaner', 'Bilaspur', 'Bokaro Steel City', 
                  'Chandigarh', 'Cuttack', 'Dehradun', 'Dhanbad', 'Bhilai', 'Durgapur', 'Dindigul', 'Erode', 'Faridabad', 
                  'Firozabad', 'Ghaziabad', 'Gorakhpur', 'Gulbarga', 'Guntur', 'Gwalior', 'Gurgaon', 'Guwahati', 
                  'Hamirpur', 'Hubli-Dharwad', 'Indore', 'Jabalpur', 'Jalandhar', 'Jammu', 'Jamnagar', 'Jamshedpur', 
                  'Jhansi', 'Jodhpur', 'Kakinada', 'Kannur', 'Kanpur', 'Karnal', 'Kochi', 'Kolhapur', 'Kollam', 
                  'Kozhikode', 'Kurnool', 'Ludhiana', 'Lucknow', 'Madurai', 'Malappuram', 'Mathura', 'Mangalore', 'Meerut', 
                  'Moradabad', 'Mysore', 'Nagpur', 'Nanded', 'Nashik', 'Nellore', 'Noida', 'Patna', 'Pondicherry', 
                  'Purulia', 'Prayagraj', 'Raipur', 'Rajkot', 'Rajahmundry', 'Ranchi', 'Rourkela', 'Salem', 'Sangli', 
                  'Shimla', 'Siliguri', 'Solapur', 'Srinagar', 'Surat', 'Thanjavur', 'Thiruvananthapuram', 'Thrissur', 
                  'Tiruchirappalli', 'Tirunelveli', 'Ujjain', 'Bijapur', 'Vadodara', 'Varanasi', 'Vasai-Virar City', 
                  'Vijayawada', 'Visakhapatnam', 'Vellore', 'Warangal']

cities_alt = {get_soundex('Bendakaluru'):'Bangalore', get_soundex('Madras'):'Chennai', get_soundex('New Delhi'):'Delhi', 
              get_soundex('Calcutta'):'Kolkata', get_soundex('Bombay'):'Mumbai', get_soundex('Belagavi'):'Belgaum', 
              get_soundex('Hubli'):'Hubli-Dharwad', get_soundex('Dharwad'):'Hubli-Dharwad', 
              get_soundex('Cawnpore'):'Kanpur', get_soundex('Cochin'):'Kochi', get_soundex('Calicut'):'Kozhikode', 
              get_soundex('Puducherry'):'Pondicherry', get_soundex('Tanjore'):'Thanjavur', 
              get_soundex('Trivandrum'):'Thiruvananthapuram', get_soundex('Trichinapoly'):'Tiruchirappalli', 
              get_soundex('Vijayapura'):'Bijapur', get_soundex('Baroda'):'Vadodara', get_soundex('Banares'):'Varanasi', 
              get_soundex('Vasai'):'Vasai-Virar City', get_soundex('Virar'):'Vasai-Virar City', 
              get_soundex('Vizag'):'Visakhapatnam'}

# %%
cities = {}

# Get the soundex code of each city and create a dictionary
for city in city_list:
    cities.update({get_soundex(city):city})

# Get the user selected location
loc = 'Bendakalooru'

# Check if the user selected city is in the list
if get_soundex(loc) in cities.keys():
    # If yes, get the correct city name
    city = cities[get_soundex(loc)]
# else check if the name entered is the alternate name of the city
elif get_soundex(loc) in cities_alt.keys():
    # yes, hence map it to the correct city name
    city = cities_alt[get_soundex(loc)]
else:
    # City is not in the list
    city = 'unlisted'
    
city

# %%
category_dictionary = zomato.get_cuisines('mumbai')
category_dictionary

# %%
city_ID = zomato.get_city_ID('pune')
city_ID

# %%
        print("i am inside action_check_cuisine")
        # Available cuisines and their soundex codes
        cuisines = {get_soundex('chinese'):'chinese', get_soundex('mexican'):'mexican', get_soundex('italian'):'italian', get_soundex('american'):'american', 
                    get_soundex('south indian'):'south indian', get_soundex('north indian'):'north indian'}

        # cuisine dropdown
        cuisines_dropdown = {'1':'chinese', '2':'mexican', '3':'italian', '4':'american', '5':'south indian', '6':'north indian'}

        # Get the user selected cuisine
        cuisine = 'Chinese'
        print(cuisine)
        cuisine = cuisine.lower()
        # Check if the user has chosen from the dropdown or directly entered the cuisine
        # If user has chosen using the dropdown
        if cuisine in cuisines_dropdown.values():
            # If yes, get the correct cuisine name
            cuisine = cuisine
        # User has directly input the cuisine choice
        else:
            # Check if the user selected cuisine is in the list
            print("else")
            if get_soundex(cuisine) in cuisines.keys():
                # If yes, get the correct cuisine name
                cuisine = cuisines[get_soundex(cuisine)]
                print(cuisine)
            else:
                # Cuisine is not in the list
                # This also means user does not have any cuisine preference. So the search will also be generic
                cuisine = 'unlisted'

        # Output pre-defined message if the cuisine is not in the list
#		if cuisine == 'unlisted':
#			dispatcher.utter_message("Sorry, we don’t have reastaurants with that cuisine right now. Please specify some other cuisine")
        print(cuisine)

# %% [markdown]
# - [south indian](cuisine:South Indian)

# %%
list(cuisines_dropdown.values())[cuisine]

# %%
cuisines_dropdown['1']

# %%
cuisines.keys()

# %%
city_name = zomato.get_city_name(10)

# %%
establishment_types_dictionary = zomato.get_establishment_types(10)
establishment_types_dictionary

# %%
wee = zomato.is_valid_city_id(abc)
wee

# %%
get_soundex('Bendakaluru')

# %%
get_soundex('Bangalore')

# %%
get_soundex('less')

# %%
get_soundex('lesser than')

# %%
price_range = {'1':[0,300], '2':[300,700], '3':[700]}
price = '1'

# %%
lll = float(price)
lll

# %%
price = '1.2'
if float(price) in range(1,4):
    print('yes')

# %%
import re

# %%
word = '< 200'
comparators = {'<=':'lesser','>=':'greater','<':'lesser','>':'greater','=':''}
rupee = ['rs.','rs','rupees.','rupee.','rupees','rupee']

# Remove the word Rupee and similar words if present as it is not needed
for r in rupee:
    if r.lower() in word:
        word = word.replace(r, '')
print(word)

# Lower limit words for the price range
price_low = ['maximum', 'max', 'less than', 'lesser than', 'cheaper than'
             'not more than', 'within', 'not above', '<=', '<']   #'below',
# Higher limit words for the price range
price_hi = ['minimum', 'min', 'more than', 'higher than',
            'not less than', 'not lesser than', 'not below', '>=', '>']  #'above',

# %%
for c in comparators:
    if c in word:
        print(comparators[c])
        break

# %%
word = 'Rs.400'
for r in rupee:
    if r in word:
        word1 = word.replace(r, '')
        break
print(word1)

# %%
word = 'below Rs.360'
word = word.lower()
price_range = '45'

# Remove the word Rupee and similar words if present as it is not needed
for r in rupee:
    if r.lower() in word:
        word = word.replace(r, '')

# This is a special case. 
# User could say "Find me restaurants below Rs. 500" or he could say "Find me restaurants not below Rs. 500"
# First case is finding a cheaper restaurant and second case is finding an expensive restaurant
if ('below' in word) and ('not' not in word):
    word = word.replace('below', 'less than')
    
# If the user has provided the upper limit for the price range 
# (for example "within Rs.400", "cheaper than Rs.500", etc)
for p in price_low:
#    if re.search(p, word):
    if p in word:
        # Extract the amount
        amount = float(re.findall(r'\d+', word)[0])
        if amount < 300:
            # It is low price range
            price_range = "1"
        elif (amount >= 300) and (amount <= 700):
            # It is mid price range
            price_range = "2"
        elif amount > 700:
            # It is high price range
            price_range = "3"
        else:
            # This code will not get executed in normal scenario
            # Choose default i.e. mid range
            price_range = "2"
        break

print(price_range)
word

# %%
word = '>=300'
word = word.lower()
price_range = '45'

# Remove the word Rupee and similar words if present as it is not needed
for r in rupee:
    if r.lower() in word:
        word = word.replace(r, '')
        break

# This is a special case. 
# User could say "Find me restaurants above Rs. 500" or he could say "Find me restaurants not above Rs. 500"
# First case is finding an expensive restaurant and second case is finding a cheaper restaurant
if ('above' in word) and ('not' not in word):
    word = word.replace('above', 'more than')
    
# If the user has provided the lower limit for the price range 
# (for example "minimum Rs.400", "more than Rs.500", etc)
for p in price_hi:
#    if re.search(p, word):
    if p in word:
        # Extract the amount
        amount = float(re.findall(r'\d+', word)[0])
        if 700 < amount:
            # It is high price range
            price_range = "3"
        elif (700 >= amount) and (300 <= amount):
            # It is mid price range
            price_range = "2"
        elif 300 > amount:
            # It is low price range
            price_range = "1"
        else:
            # This code will not get executed in normal scenario
            # Choose default i.e. mid range
            price_range = "2"
        break

print(price_range)
word

# %%
word = 'Rs400'
a = float(re.findall(r'\d+', word)[0])
a

# %%
word = '=>360'
word = word.lower()
if ('=' in word) and ('>=' not in word) and ('<=' not in word):
    word = word.replace('=', 'less than')
word

# %%
word = 'between Rupees 300 to Rupees. 500'
word = word.lower()
rupee = ['rs.','rs','rupees.','rupee.','rupees','rupee']
# Remove the word Rupee and similar words if present as it is not needed
for r in rupee:
    if r.lower() in word:
        word = word.replace(r, '')
#        break
word

# %%
word = '3  '
if re.search(r'^[\s]*\d+[\s]*$', word):
    print(word.strip(' '))

# %%
price = 'from 200to300'
len(re.findall(r'\d+', price))
price = sorted(re.findall(r'\d+', price))[1]
price

# %%
price = '>200 <500'

# %%
		# Upper limit words for the price range
		price_low = ['maximum', 'max', 'less than', 'lesser than', 'cheaper than' 'not more than', 'within', 'not above', '<=', '<']
		# Lower limit words for the price range
		price_hi = ['minimum', 'min', 'more than', 'higher than', 'not less than', 'not lesser than', 'not below', '>=', '>']

		# Remove the word Rupee or similar words if present as it is not needed		
		rupee = ['Rs.','Rs','Rupees.','Rupee.','Rupees','Rupee']
		for r in rupee:
    		if r.lower() in price:
        		price = price.replace(r, '')
		
		# User could say "Find me restaurants between Rs.300 and Rs.500"
		# Check if there are two numbers present in the string
		if len(re.findall(r'\d+', price)) == 2:
			# Consider the upper limit as the price (e.g.: in Rs.300 and Rs.500, it will select 500)
			price = sorted(re.findall(r'\d+', price))[1]

		# If it is a pure number, then it is either the price range option (1, 2 or 3), or directly holds the amount
		if re.search(r'^[\s]*\d+[\s]*$', price):
			# Remove white spaces if any
			price = price.strip(" ")
			# Check if the user has chosen using the dropdown i.e. if the slot 'price' already has the value 1, 2 or 3
			if float(price) in range(1,4):
				# If yes, then correct price range is mentioned
				price_range = price
			# Check if the user has directly input the price range, then assign the proper value to the slot 'price' accordingly
			elif float(price) < 300:
				# It is in low price range
				price_range = "1"
			elif (float(price) >= 300) and (float(price) <= 700):
				# It is in mid price range
				price_range = "2"
			elif float(price) > 700:
				# It is in high price range
				price_range = "3"
			else:
				# Price is not mentioned
				# Choose default i.e. mid range
				price_range = "2"
		# It is not a pure number. It means it contains a string. Extract the price (which will be a number) and determine the price range
		else:
			# At first, three special cases are considered: 
			# User could say "Find me restaurants below Rs. 500" or he could say "Find me restaurants not below Rs. 500"
			# First case is finding a cheaper restaurant and second case is finding an expensive restaurant
			if ('below' in price) and ('not' not in price):
				price = price.replace('below', 'less than')

			# User could say "Find me restaurants above Rs. 500" or he could say "Find me restaurants not above Rs. 500"
			# First case is finding an expensive restaurant and second case is finding a cheaper restaurant
			if ('above' in price) and ('not' not in price):
				price = price.replace('above', 'more than')

			# User could say "Find me restaurants priced = 500"
			# '=' can be considered as user wants to consider restaurant budget below that amount
			if ('=' in price) and ('>=' not in price) and ('<=' not in price):
				price = price.replace('=', 'less than')

			# If the user has provided the upper limit for the price range 
			# (for example "within Rs.400", "cheaper than Rs.500", etc)
			for p in price_low:
				if p in price:
					# Extract the amount
					amount = float(re.findall(r'\d+', price)[0])
					if amount < 300:
						# It is in low price range
						price_range = "1"
					elif (amount >= 300) and (amount <= 700):
						# It is in mid price range
						price_range = "2"
					elif amount > 700:
						# It is in high price range
						price_range = "3"
					else:
						# Choose default i.e. mid range
						price_range = "2"
					break

			# If the user has provided the lower limit for the price range 
			# (for example "minimum Rs.400", "more than Rs.500", etc)
			for p in price_hi:
				if p in price:
					# Extract the amount
					amount = float(re.findall(r'\d+', price)[0])
					if 700 < amount:
						# It is in high price range
						price_range = "3"
					elif (700 >= amount) and (300 <= amount):
						# It is in mid price range
						price_range = "2"
					elif 300 > amount:
						# It is in low price range
						price_range = "1"
					else:
						# Choose default i.e. mid range
						price_range = "2"
					break
print(price_range)

# %%
import zomatopy
import smtplib,ssl

# %%
body="test"

from_user = 'restosearch.bot@gmail.com'
password = 'restobotrasa123'
#to="raj29shenoy@gmail.com"
to = 'anindyasudhir@gmail.com'
subject = 'Foodie has found you the restaurants'
msg = MIMEMultipart()
            msg['From'] = from_user
            msg['TO'] = to
            msg['Subject'] = subject
email_text= """
test email
"""
print(email_text)
try:  
    # Create a secure SSL context
    context = ssl.create_default_context()

    with smtplib.SMTP_SSL("smtp.gmail.com", 465, context=context) as server:
        server.login(from_user, password)
        server.sendmail(from_user,to,body)
        server.close()
except Exception as e:		
	
	print(e)

# %%
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart

# %%
            from_user = 'restosearch.bot@gmail.com'
            password = 'restobotrasa123'
            subject = 'Foodie has found you the restaurants'
            msg = MIMEMultipart()
            msg['From'] = from_user
            msg['TO'] = 'anindyasudhir@gmail.com'
            msg['Subject'] = subject
            # Read the search results
            rest_name = []
            rest_address = []
            rest_rating = []
            rest_budget = []
            for res in response[::2]:
                rest_name.append(res.split(' in ')[0])
                rest_address.append(res.split(' in ')[1].split(' has a rating of ')[0])
                rest_rating.append(res.split(' in ')[1].split(' has a rating of ')[1][:-1])
            for budget in response[1::2]:
                rest_budget.append(budget[:-1])
            txt = ""
            for idx in range(10):
                txt = txt + '<b>Restaurant Name:</b> ' + rest_name[idx] + '<br>'
                txt = txt + '<b>Restaurant locality address:</b> ' + rest_address[idx] + '<br>'
                txt = txt + '<b>Budget:</b> ' + rest_budget[idx] + '<br>'
                txt = txt + '<b>Zomato user rating:</b> ' + rest_rating[idx] + '<br>'
                txt = txt + '<br>'
            html = """\
                    <html>
                      <body>
                        <p>Greetings from RestoBot!,<br>
                           <h3>Here are the top rated restaurants as per your criteria:</h3> <br>"""
            html = html + txt
            html = html + """
                           <br><b><i>Itadakimasu,</b></i><br><b>RestoBot Team</b>
                        </p>
                      </body>
                    </html>
                    """
            msg.attach(MIMEText(html,'html'))
            text = msg.as_string()
            print(text)
           # Create a secure SSL context
            try:
                context = ssl.create_default_context()
                with smtplib.SMTP_SSL("smtp.gmail.com", 465, context=context) as server:
                    server.login(from_user,password)
                    server.sendmail(from_user,to,text)
                    server.close()
            except Exception as e:
                print(e)

# %%
response

# %%
type(html)

# %%
html = """\
                    <html>
                      <body>
                        <p>Greetings from RestoBot!,<br>
                           Here are the top rated restaurants as per your criteria: <br> """
html = html + "1"

# %%
rest_name = []
rest_address = []
rest_rating = []
rest_budget = []
for res in response[::2]:
    rest_name.append(res.split(' in ')[0])
    rest_address.append(res.split(' in ')[1].split(' has a rating of ')[0])
    rest_rating.append(res.split(' in ')[1].split(' has a rating of ')[1][:-1])
for budget in response[1::2]:
    rest_budget.append(budget[:-1])
txt = ""
for idx in range(10):
    txt = txt + '<b>Restaurant Name:</b> ' + rest_name[idx] + '<br>'
    txt = txt + '<b>Restaurant locality address:</b> ' + rest_address[idx] + '<br>'
    txt = txt + '<b>Budget:</b> ' + rest_budget[idx] + '<br>'
    txt = txt + '<b>Zomato user rating:</b> ' + rest_rating[idx] + '<br>'
    txt = txt + '<br>'

# %%
txt

# %%
for offset in range(0, 50, 20):
    print(offset)

# %%
len(response)//2

# %%
for idx in range(len(response)//2):
    print(idx)

# %%
import time
start_time = time.time()
zomatoData = []
for offset in range(0, 100, 20):
        results = zomato.restaurant_search_by_city(city_id, str(cuisines_dict[cuisine]), offset)
        zomatoData.append(json.loads(results))

print("--- %s seconds ---" % (time.time() - start_time))

# %%
import grequests

urls = ['http://www.google.com/finance','http://finance.yahoo.com/','http://www.bloomberg.com/']

def print_url(r, **kwargs):
    print(r.url)

def async(url_list)
    sites = []
    for u in url_list:
        rs = grequests.get(u, hooks=dict(response=print_url))
        sites.append(rs)
    return grequests.map(sites)

print async(urls)

# %%
#!/usr/local/bin/python3.5
import asyncio
from aiohttp import ClientSession

async def hello(url):
    
    r = ""
    async with ClientSession() as session:
        async with session.get(url) as response:
            response = await response.read()
            r = (response.decode("utf-8"))            
    return r
loop = asyncio.get_event_loop()

if loop.is_running() == False:
    asyncio.run(print(hello("http://httpbin.org/headers")))
else:
    val = await hello("http://httpbin.org/headers")
print(val)

# %%
import aiohttp
import asyncio
import async_timeout

async def fetch(session, url):
    with async_timeout.timeout(10):
        async with session.get(url).content as response:
            return await response.text()

async def main():
    async with aiohttp.ClientSession() as session:
        html = await fetch(session, 'http://python.org')
        print(html)


main()
